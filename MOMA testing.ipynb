# %%
from math import isinf
import cobra
import escher
import json
import os
from IPython.display import HTML
import matplotlib
import matplotlib.pyplot as plt

# %%
model = cobra.io.read_sbml_model('iJO1366.xml')

# %%
model.summary()
# Out:
# IN FLUXES            OUT FLUXES    OBJECTIVES
# -------------------  ------------  ----------------------
# o2_e      17.6       h2o_e  45.6   BIOMASS_Ec_i...  0.982
# nh4_e     10.6       co2_e  19.7
# glc__D_e  10         h_e     9.03
# pi_e       0.948
# so4_e      0.248
# k_e        0.192
# fe2_e      0.0158
# mg2_e      0.00852
# ca2_e      0.00511
# cl_e       0.00511
# cu2_e      0.000697
# mn2_e      0.000679
# zn2_e      0.000335
# ni2_e      0.000317
# mobd_e     0.000127

# %%
# Como ajustar o bounds
# uma maneira facil para quem nao percebe nada de constraints
model.medium
# Out:
# {'EX_ca2_e': 1000.0,
#  'EX_cbl1_e': 0.01,
#  'EX_cl_e': 1000.0,
#  'EX_co2_e': 1000.0,
#  'EX_cobalt2_e': 1000.0,
#  'EX_cu2_e': 1000.0,
#  'EX_fe2_e': 1000.0,
#  'EX_fe3_e': 1000.0,
#  'EX_glc__D_e': 10.0,
#  'EX_h_e': 1000.0,
#  'EX_h2o_e': 1000.0,
#  'EX_k_e': 1000.0,
#  'EX_mg2_e': 1000.0,
#  'EX_mn2_e': 1000.0,
#  'EX_mobd_e': 1000.0,
#  'EX_na1_e': 1000.0,
#  'EX_nh4_e': 1000.0,
#  'EX_ni2_e': 1000.0,
#  'EX_o2_e': 1000.0,
#  'EX_pi_e': 1000.0,
#  'EX_sel_e': 1000.0,
#  'EX_slnt_e': 1000.0,
#  'EX_so4_e': 1000.0,
#  'EX_tungs_e': 1000.0,
#  'EX_zn2_e': 1000.0}

# %%
# outra/melhor forma, controalr directamenet a reaccao do exchange
# usar um loop para identificar exchange reactions e filtrar por lower bound not 0
for r in model.reactions:
    if 'EX_' in r.id and not r.lower_bound==0:
        print(r,r.lower_bound,r.upper_bound)
# Out:
# EX_ca2_e: ca2_e <=>  -1000.0 1000.0
# EX_cbl1_e: cbl1_e <=>  -0.01 1000.0
# EX_cl_e: cl_e <=>  -1000.0 1000.0
# EX_co2_e: co2_e <=>  -1000.0 1000.0
# EX_cobalt2_e: cobalt2_e <=>  -1000.0 1000.0
# EX_cu2_e: cu2_e <=>  -1000.0 1000.0
# EX_fe2_e: fe2_e <=>  -1000.0 1000.0
# EX_fe3_e: fe3_e <=>  -1000.0 1000.0
# EX_glc__D_e: glc__D_e <=>  -10.0 1000.0
# EX_h_e: h_e <=>  -1000.0 1000.0
# EX_h2o_e: h2o_e <=>  -1000.0 1000.0
# EX_k_e: k_e <=>  -1000.0 1000.0
# EX_mg2_e: mg2_e <=>  -1000.0 1000.0
# EX_mn2_e: mn2_e <=>  -1000.0 1000.0
# EX_mobd_e: mobd_e <=>  -1000.0 1000.0
# EX_na1_e: na1_e <=>  -1000.0 1000.0
# EX_nh4_e: nh4_e <=>  -1000.0 1000.0
# EX_ni2_e: ni2_e <=>  -1000.0 1000.0
# EX_o2_e: o2_e <=>  -1000.0 1000.0
# EX_pi_e: pi_e <=>  -1000.0 1000.0
# EX_sel_e: sel_e <=>  -1000.0 1000.0
# EX_slnt_e: slnt_e <=>  -1000.0 1000.0
# EX_so4_e: so4_e <=>  -1000.0 1000.0
# EX_tungs_e: tungs_e <=>  -1000.0 1000.0
# EX_zn2_e: zn2_e <=>  -1000.0 1000.0

# %%
# mudar bound da glucose e oxigenio de acordo com o ijo1366 paper para aerobic growth on glucose
model.reactions.EX_glc__D_e.lower_bound=-8
model.reactions.EX_o2_e.lower_bound=-18.5
for r in model.reactions:
    if 'EX_' in r.id and not r.lower_bound==0:
        print(r,r.lower_bound,r.upper_bound)
model.summary()
# Out:
# EX_ca2_e: ca2_e <=>  -1000.0 1000.0
# EX_cbl1_e: cbl1_e <=>  -0.01 1000.0
# EX_cl_e: cl_e <=>  -1000.0 1000.0
# EX_co2_e: co2_e <=>  -1000.0 1000.0
# EX_cobalt2_e: cobalt2_e <=>  -1000.0 1000.0
# EX_cu2_e: cu2_e <=>  -1000.0 1000.0
# EX_fe2_e: fe2_e <=>  -1000.0 1000.0
# EX_fe3_e: fe3_e <=>  -1000.0 1000.0
# EX_glc__D_e: glc__D_e <=>  -8 1000.0
# EX_h_e: h_e <=>  -1000.0 1000.0
# EX_h2o_e: h2o_e <=>  -1000.0 1000.0
# EX_k_e: k_e <=>  -1000.0 1000.0
# EX_mg2_e: mg2_e <=>  -1000.0 1000.0
# EX_mn2_e: mn2_e <=>  -1000.0 1000.0
# EX_mobd_e: mobd_e <=>  -1000.0 1000.0
# EX_na1_e: na1_e <=>  -1000.0 1000.0
# EX_nh4_e: nh4_e <=>  -1000.0 1000.0
# EX_ni2_e: ni2_e <=>  -1000.0 1000.0
# EX_o2_e: o2_e <=>  -18.5 1000.0
# EX_pi_e: pi_e <=>  -1000.0 1000.0
# EX_sel_e: sel_e <=>  -1000.0 1000.0
# EX_slnt_e: slnt_e <=>  -1000.0 1000.0
# EX_so4_e: so4_e <=>  -1000.0 1000.0
# EX_tungs_e: tungs_e <=>  -1000.0 1000.0
# EX_zn2_e: zn2_e <=>  -1000.0 1000.0
# IN FLUXES            OUT FLUXES    OBJECTIVES
# -------------------  ------------  ----------------------
# o2_e      14.2       h2o_e  36.5   BIOMASS_Ec_i...  0.783
# nh4_e      8.46      co2_e  15.8
# glc__D_e   8         h_e     7.2
# pi_e       0.756
# so4_e      0.198
# k_e        0.153
# fe2_e      0.0126
# mg2_e      0.00679
# ca2_e      0.00408
# cl_e       0.00408
# cu2_e      0.000555
# mn2_e      0.000541
# zn2_e      0.000267
# ni2_e      0.000253
# mobd_e     0.000101

# %%
# do "escher."to see differwnt avialble maps, and different types of getting maps
escher.list_cached_maps()
#escher.list_cached_models()
# Out:
# [{'organism': 'Escherichia coli', 'map_name': 'map_v2'},
#  {'organism': 'Escherichia coli', 'map_name': 'iJO1366.Central metabolism'},
#  {'organism': 'Escherichia coli', 'map_name': 'map_v1'},
#  {'organism': 'Escherichia coli', 'map_name': 'new_map'}]

# %%
#escher
b = escher.Builder(map_name='map_v1', local_host='https://escher.github.io')
b.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="awshpunseq"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"awshpunseq"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": null, "metabolite_data": null, "gene_data": null}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name":"new_map","map_id":"qfenoSUczSPO","map_description":"\\nLast Modified Fri Nov 16 2018 10:14:12 GMT-0600 (Central Standard Time)","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"0":{"name":"Aspartate transaminase","bigg_id":"ASPTA","reversibility":true,"label_x":-531,"label_y":168.00003051757815,"gene_reaction_rule":"b0928","genes":[{"notes":{"original_bigg_ids":["b0928"]},"name":"aspC","bigg_id":"b0928"}],"metabolites":[{"bigg_id":"akg_c","coefficient":-1},{"bigg_id":"asp__L_c","coefficient":-1},{"bigg_id":"glu__L_c","coefficient":1},{"bigg_id":"oaa_c","coefficient":1}],"segments":{"0":{"from_node_id":"1","to_node_id":"2","b1":null,"b2":null},"1":{"from_node_id":"3","to_node_id":"2","b1":null,"b2":null},"2":{"from_node_id":"1","to_node_id":"0","b1":{"x":-419,"y":208.00003051757812},"b2":{"x":-366.0833435058594,"y":209.33335876464844}},"3":{"from_node_id":"1","to_node_id":"4","b1":{"x":-415,"y":208.00003051757812},"b2":{"x":-385.7499694824219,"y":160.66669464111328}},"4":{"from_node_id":"3","to_node_id":"5","b1":{"x":-543,"y":208.00003051757815},"b2":{"x":-597.25,"y":208.00003051757815}},"5":{"from_node_id":"3","to_node_id":"6","b1":{"x":-547,"y":208.00003051757815},"b2":{"x":-563.167724609375,"y":158.28127288818362}}}},"1":{"name":"Oxaloacetate decarboxylase","bigg_id":"OAADC","reversibility":false,"label_x":-570.4681396484375,"label_y":-1321.0993995666504,"gene_reaction_rule":"b1850","genes":[{"notes":{"original_bigg_ids":["b1850"]},"name":"eda","bigg_id":"b1850"}],"metabolites":[{"bigg_id":"pyr_c","coefficient":1},{"bigg_id":"co2_c","coefficient":1},{"bigg_id":"h_c","coefficient":-1},{"bigg_id":"oaa_c","coefficient":-1}],"segments":{"6":{"from_node_id":"7","to_node_id":"8","b1":null,"b2":null},"7":{"from_node_id":"9","to_node_id":"8","b1":null,"b2":null},"8":{"from_node_id":"9","to_node_id":"10","b1":{"x":-585.4681396484375,"y":-1393.0993995666504},"b2":{"x":-584.1348266601562,"y":-1583.3493995666504}},"9":{"from_node_id":"9","to_node_id":"11","b1":{"x":-585.4681396484375,"y":-1397.0993995666504},"b2":{"x":-571.8448181152344,"y":-1425.691562652588}},"10":{"from_node_id":"7","to_node_id":"12","b1":{"x":-585.4681396484375,"y":-1265.0993995666504},"b2":{"x":-576.2214050292969,"y":-1230.671787261963}},"11":{"from_node_id":"7","to_node_id":"6","b1":{"x":-585.4681396484375,"y":-1269.0993995666504},"b2":{"x":-596.917724609375,"y":37.53127288818362}}}},"3":{"name":"Aspartate 1-decarboxylase","bigg_id":"ASP1DC","reversibility":false,"label_x":-336.9999694824219,"label_y":-66.33330535888672,"gene_reaction_rule":"b0131","genes":[{"notes":{"original_bigg_ids":["b0131"]},"name":"panD","bigg_id":"b0131"}],"metabolites":[{"bigg_id":"asp__L_c","coefficient":-1},{"bigg_id":"co2_c","coefficient":1},{"bigg_id":"h_c","coefficient":-1},{"bigg_id":"ala_B_c","coefficient":1}],"segments":{"18":{"from_node_id":"19","to_node_id":"20","b1":null,"b2":null},"19":{"from_node_id":"21","to_node_id":"20","b1":null,"b2":null},"20":{"from_node_id":"19","to_node_id":"4","b1":{"x":-351.9999694824219,"y":-14.333305358886719},"b2":{"x":-351.9999694824219,"y":39.91669464111328}},"21":{"from_node_id":"21","to_node_id":"22","b1":{"x":-351.9999694824219,"y":-142.33330535888672},"b2":{"x":-333.9999694824219,"y":-147.58330535888672}},"22":{"from_node_id":"19","to_node_id":"23","b1":{"x":-351.9999694824219,"y":-10.333305358886719},"b2":{"x":-333.9999694824219,"y":-5.083305358886719}},"23":{"from_node_id":"21","to_node_id":"24","b1":{"x":-351.9999694824219,"y":-138.33330535888672},"b2":{"x":-351.9999694824219,"y":-192.58330535888672}}}},"5":{"name":"Aspartate kinase","bigg_id":"ASPK","reversibility":true,"label_x":-157.66663360595703,"label_y":142.66668701171875,"gene_reaction_rule":"b0002 or b3940 or b4024","genes":[{"notes":{"original_bigg_ids":["b0002"]},"name":"thrA","bigg_id":"b0002"},{"notes":{"original_bigg_ids":["b3940"]},"name":"metL","bigg_id":"b ...

# %%
#ver qual e a biomassa que esta a ser usada
print(model.objective)
# Out:
# Maximize
# -1.0*BIOMASS_Ec_iJO1366_core_53p95M_reverse_5c8b1 + 1.0*BIOMASS_Ec_iJO1366_core_53p95M

# %%
# mudar biomassa do core para WT
model_biomass = 'BIOMASS_Ec_iJO1366_WT_53p95M'
model.objective= model_biomass
print(model.objective)
# Out:
# Maximize
# -1.0*BIOMASS_Ec_iJO1366_WT_53p95M_reverse_06c4a + 1.0*BIOMASS_Ec_iJO1366_WT_53p95M

# %%
# corre FBA e pFBA
fba_solution = model.optimize()
pfba_solution = cobra.flux_analysis.pfba(model)
print(model.objective)
# Out:
# Maximize
# -1.0*BIOMASS_Ec_iJO1366_WT_53p95M_reverse_06c4a + 1.0*BIOMASS_Ec_iJO1366_WT_53p95M

# %%
# comparar pFBA andf FBA
# o objctivo do pFBA e minimizar a soma dos fluxos, mas para ver o biomass flux temos de ver directamente 
#o flux da reaccao da biomass
print('FBA Ovalue', fba_solution.objective_value, 'pFBA Ovalue', pfba_solution.objective_value)
print('FBA Biomass',fba_solution.fluxes.BIOMASS_Ec_iJO1366_WT_53p95M, 'pFBA biomass', pfba_solution.fluxes.BIOMASS_Ec_iJO1366_WT_53p95M)
# Out:
# FBA Ovalue 0.7865875166015222 pFBA Ovalue 557.2926358538784
# FBA Biomass 0.7865875166015222 pFBA biomass 0.7865875166015222

# %%
# pintar WT no nosso mapa

# pintar fluxos no escher
# {} dicionario vazio
# escher
# fazer free draw das reaccoes

#b = escher.Builder(reaction_data={'FRD3':1,'SUCOAS':-1}, map_name='iJO1366.Central metabolism', local_host='https://escher.github.io')
#b.display_in_notebook()

# criar o dicionario para pintar a solucao num mapa
# o break ajuda a ver so a primeira linha
WT_sol1={}
for r in model.reactions:
    
    # prints e break para debug
    #print(r, pfba_solution.fluxes[r.id])
    #break
    WT_sol1[r.id]=pfba_solution.fluxes[r.id]
    
#para confirmar que esta correcto    
#WT_sol1

b = escher.Builder(reaction_data=WT_sol1, map_name='map_v1', local_host='https://escher.github.io')
b.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="ufpujbevkb"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"ufpujbevkb"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": {"DM_4crsol_c": 0.00017540901620213944, "DM_5drib_c": 0.00018170171633494648, "DM_aacald_c": 0.0, "DM_amob_c": 1.5731750332030442e-06, "DM_mththf_c": 0.001054027272246058, "DM_oxam_c": 0.0, "BIOMASS_Ec_iJO1366_WT_53p95M": 0.7865875166015222, "BIOMASS_Ec_iJO1366_core_53p95M": 0.0, "EX_12ppd__R_e": 0.0, "EX_12ppd__S_e": 0.0, "EX_14glucan_e": 0.0, "EX_15dap_e": 0.0, "EX_23camp_e": 0.0, "EX_23ccmp_e": 0.0, "EX_23cgmp_e": 0.0, "EX_23cump_e": 0.0, "EX_23dappa_e": 0.0, "EX_26dap__M_e": 0.0, "EX_2ddglcn_e": 0.0, "EX_34dhpac_e": 0.0, "EX_3amp_e": 0.0, "EX_3cmp_e": 0.0, "EX_3gmp_e": 0.0, "EX_3hcinnm_e": 0.0, "EX_3hpp_e": 0.0, "EX_3hpppn_e": 0.0, "EX_3ump_e": 0.0, "EX_4abut_e": 0.0, "EX_4hoxpacd_e": 0.0, "EX_5dglcn_e": 0.0, "EX_5mtr_e": 0.005304746211960665, "EX_LalaDglu_e": 0.0, "EX_LalaDgluMdap_e": 0.0, "EX_LalaDgluMdapDala_e": 0.0, "EX_LalaLglu_e": 0.0, "EX_ac_e": -6.202434632269275e-14, "EX_acac_e": 0.0, "EX_acald_e": 0.0, "EX_acgal_e": 0.0, "EX_acgal1p_e": 0.0, "EX_acgam_e": 0.0, "EX_acgam1p_e": 0.0, "EX_acmana_e": 0.0, "EX_acmum_e": 0.0, "EX_acnam_e": 0.0, "EX_acolipa_e": 0.0, "EX_acser_e": 0.0, "EX_ade_e": 0.0, "EX_adn_e": 0.0, "EX_adocbl_e": 0.0, "EX_ag_e": 0.0, "EX_agm_e": 0.0, "EX_akg_e": 0.0, "EX_ala_B_e": 0.0, "EX_ala__D_e": 0.0, "EX_ala__L_e": 0.0, "EX_alaala_e": 0.0, "EX_all__D_e": 0.0, "EX_alltn_e": 0.0, "EX_amp_e": 0.0, "EX_anhgm_e": 0.0, "EX_arab__L_e": 0.0, "EX_arbt_e": 0.0, "EX_arbtn_e": 0.0, "EX_arbtn_fe3_e": 0.0, "EX_arg__L_e": 0.0, "EX_ascb__L_e": 0.0, "EX_asn__L_e": 0.0, "EX_aso3_e": 0.0, "EX_asp__L_e": 0.0, "EX_btn_e": 0.0, "EX_but_e": 0.0, "EX_butso3_e": 0.0, "EX_ca2_e": -0.0038951813822107376, "EX_cbi_e": 0.0, "EX_cbl1_e": -0.00017540901620213944, "EX_cd2_e": 0.0, "EX_cgly_e": 0.0, "EX_chol_e": 0.0, "EX_chtbs_e": 0.0, "EX_cit_e": 0.0, "EX_cl_e": -0.0038951813822107376, "EX_cm_e": 0.0, "EX_cmp_e": 0.0, "EX_co2_e": 15.832896802339356, "EX_cobalt2_e": -1.887810039843653e-05, "EX_colipa_e": 0.0, "EX_colipap_e": 0.0, "EX_cpgn_e": 0.0, "EX_cpgn_un_e": 0.0, "EX_crn_e": 0.0, "EX_crn__D_e": 0.0, "EX_csn_e": 0.0, "EX_cu_e": 0.0, "EX_cu2_e": -0.0005301599861894259, "EX_cyan_e": 0.0, "EX_cynt_e": 0.0, "EX_cys__D_e": 0.0, "EX_cys__L_e": 0.0, "EX_cytd_e": 0.0, "EX_dad_2_e": 0.0, "EX_damp_e": 0.0, "EX_dca_e": 0.0, "EX_dcmp_e": 0.0, "EX_dcyt_e": 0.0, "EX_ddca_e": 0.0, "EX_dgmp_e": 0.0, "EX_dgsn_e": 0.0, "EX_dha_e": 0.0, "EX_dimp_e": 0.0, "EX_din_e": 0.0, "EX_dms_e": 0.0, "EX_dmso_e": 0.0, "EX_dopa_e": 0.0, "EX_doxrbcn_e": 0.0, "EX_dtmp_e": 0.0, "EX_dump_e": 0.0, "EX_duri_e": 0.0, "EX_eca4colipa_e": 0.0, "EX_enlipa_e": 0.0, "EX_enter_e": 0.0, "EX_etha_e": 0.0, "EX_ethso3_e": 0.0, "EX_etoh_e": 0.0, "EX_f6p_e": 0.0, "EX_fald_e": 0.0, "EX_fe2_e": -0.012213344370271835, "EX_fe3_e": 0.0, "EX_fe3dcit_e": 0.0, "EX_fe3dhbzs_e": 0.0, "EX_fe3hox_e": 0.0, "EX_fe3hox_un_e": 0.0, "EX_fecrm_e": 0.0, "EX_fecrm_un_e": 0.0, "EX_feenter_e": 0.0, "EX_feoxam_e": 0.0, "EX_feoxam_un_e": 0.0, "EX_for_e": 0.0, "EX_fru_e": 0.0, "EX_frulys_e": 0.0, "EX_fruur_e": 0.0, "EX_fuc__L_e": 0.0, "EX_fum_e": 0.0, "EX_fusa_e": 0.0, "EX_g1p_e": 0.0, "EX_g3pc_e": 0.0, "EX_g3pe_e": 0.0, "EX_g3pg_e": 0.0, "EX_g3pi_e": 0.0, "EX_g3ps_e": 0.0, "EX_g6p_e": 0.0, "EX_gal_e": 0.0, "EX_gal_bD_e": 0.0, "EX_gal1p_e": 0.0, "EX_galct__D_e": 0.0, "EX_galctn__D_e": 0.0, "EX_galctn__L_e": 0.0, "EX_galt_e": 0.0, "EX_galur_e": 0.0, "EX_gam_e": 0.0, "EX_gam6p_e": 0.0, "EX_gbbtn_e": 0.0, "EX_gdp_e": 0.0, "EX_glc__D_e": -8.0, "EX_glcn_e": 0.0, "EX_glcr_e": 0.0, "EX_glcur_e": 0.0, "EX_glcur1p_e": 0.0, "EX_gln__L_e": 0.0, "EX_glu__L_e": 0.0, "EX_gly_e": 0.0, "EX_glyald_e": 0.0, "EX_glyb_e": 0.0, "EX_glyc_e": 0.0, "EX_glyc__R_e": 0.0, "EX_glyc2p_e": 0.0, "EX_glyc3p_e": 0.0, "EX_glyclt_e": 0.0, "EX_gmp_e": 0.0, "EX_gsn_e": 0.0, "EX_gthox_e": 0.0, "EX_gthrd_e": 0.0, "EX_gtp_ ...

# %%
# pintar WT no iJO13666

# pintar fluxos no escher
# {} dicionario vazio
# escher
# fazer free draw das reaccoes

#b = escher.Builder(reaction_data={'FRD3':1,'SUCOAS':-1}, map_name='iJO1366.Central metabolism', local_host='https://escher.github.io')
#b.display_in_notebook()

# criar o dicionario para pintar a solucao num mapa
# o break ajuda a ver so a primeira linha
WT_sol1={}
for r in model.reactions:
    
    # prints e break para debug
    #print(r, pfba_solution.fluxes[r.id])
    #break
    WT_sol1[r.id]=pfba_solution.fluxes[r.id]
    
#para confirmar que esta correcto    
#WT_sol1

b = escher.Builder(reaction_data=WT_sol1, map_name='iJO1366.Central metabolism', local_host='https://escher.github.io')
b.display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="fwwajqssev"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"fwwajqssev"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": {"DM_4crsol_c": 0.00017540901620213944, "DM_5drib_c": 0.00018170171633494648, "DM_aacald_c": 0.0, "DM_amob_c": 1.5731750332030442e-06, "DM_mththf_c": 0.001054027272246058, "DM_oxam_c": 0.0, "BIOMASS_Ec_iJO1366_WT_53p95M": 0.7865875166015222, "BIOMASS_Ec_iJO1366_core_53p95M": 0.0, "EX_12ppd__R_e": 0.0, "EX_12ppd__S_e": 0.0, "EX_14glucan_e": 0.0, "EX_15dap_e": 0.0, "EX_23camp_e": 0.0, "EX_23ccmp_e": 0.0, "EX_23cgmp_e": 0.0, "EX_23cump_e": 0.0, "EX_23dappa_e": 0.0, "EX_26dap__M_e": 0.0, "EX_2ddglcn_e": 0.0, "EX_34dhpac_e": 0.0, "EX_3amp_e": 0.0, "EX_3cmp_e": 0.0, "EX_3gmp_e": 0.0, "EX_3hcinnm_e": 0.0, "EX_3hpp_e": 0.0, "EX_3hpppn_e": 0.0, "EX_3ump_e": 0.0, "EX_4abut_e": 0.0, "EX_4hoxpacd_e": 0.0, "EX_5dglcn_e": 0.0, "EX_5mtr_e": 0.005304746211960665, "EX_LalaDglu_e": 0.0, "EX_LalaDgluMdap_e": 0.0, "EX_LalaDgluMdapDala_e": 0.0, "EX_LalaLglu_e": 0.0, "EX_ac_e": -6.202434632269275e-14, "EX_acac_e": 0.0, "EX_acald_e": 0.0, "EX_acgal_e": 0.0, "EX_acgal1p_e": 0.0, "EX_acgam_e": 0.0, "EX_acgam1p_e": 0.0, "EX_acmana_e": 0.0, "EX_acmum_e": 0.0, "EX_acnam_e": 0.0, "EX_acolipa_e": 0.0, "EX_acser_e": 0.0, "EX_ade_e": 0.0, "EX_adn_e": 0.0, "EX_adocbl_e": 0.0, "EX_ag_e": 0.0, "EX_agm_e": 0.0, "EX_akg_e": 0.0, "EX_ala_B_e": 0.0, "EX_ala__D_e": 0.0, "EX_ala__L_e": 0.0, "EX_alaala_e": 0.0, "EX_all__D_e": 0.0, "EX_alltn_e": 0.0, "EX_amp_e": 0.0, "EX_anhgm_e": 0.0, "EX_arab__L_e": 0.0, "EX_arbt_e": 0.0, "EX_arbtn_e": 0.0, "EX_arbtn_fe3_e": 0.0, "EX_arg__L_e": 0.0, "EX_ascb__L_e": 0.0, "EX_asn__L_e": 0.0, "EX_aso3_e": 0.0, "EX_asp__L_e": 0.0, "EX_btn_e": 0.0, "EX_but_e": 0.0, "EX_butso3_e": 0.0, "EX_ca2_e": -0.0038951813822107376, "EX_cbi_e": 0.0, "EX_cbl1_e": -0.00017540901620213944, "EX_cd2_e": 0.0, "EX_cgly_e": 0.0, "EX_chol_e": 0.0, "EX_chtbs_e": 0.0, "EX_cit_e": 0.0, "EX_cl_e": -0.0038951813822107376, "EX_cm_e": 0.0, "EX_cmp_e": 0.0, "EX_co2_e": 15.832896802339356, "EX_cobalt2_e": -1.887810039843653e-05, "EX_colipa_e": 0.0, "EX_colipap_e": 0.0, "EX_cpgn_e": 0.0, "EX_cpgn_un_e": 0.0, "EX_crn_e": 0.0, "EX_crn__D_e": 0.0, "EX_csn_e": 0.0, "EX_cu_e": 0.0, "EX_cu2_e": -0.0005301599861894259, "EX_cyan_e": 0.0, "EX_cynt_e": 0.0, "EX_cys__D_e": 0.0, "EX_cys__L_e": 0.0, "EX_cytd_e": 0.0, "EX_dad_2_e": 0.0, "EX_damp_e": 0.0, "EX_dca_e": 0.0, "EX_dcmp_e": 0.0, "EX_dcyt_e": 0.0, "EX_ddca_e": 0.0, "EX_dgmp_e": 0.0, "EX_dgsn_e": 0.0, "EX_dha_e": 0.0, "EX_dimp_e": 0.0, "EX_din_e": 0.0, "EX_dms_e": 0.0, "EX_dmso_e": 0.0, "EX_dopa_e": 0.0, "EX_doxrbcn_e": 0.0, "EX_dtmp_e": 0.0, "EX_dump_e": 0.0, "EX_duri_e": 0.0, "EX_eca4colipa_e": 0.0, "EX_enlipa_e": 0.0, "EX_enter_e": 0.0, "EX_etha_e": 0.0, "EX_ethso3_e": 0.0, "EX_etoh_e": 0.0, "EX_f6p_e": 0.0, "EX_fald_e": 0.0, "EX_fe2_e": -0.012213344370271835, "EX_fe3_e": 0.0, "EX_fe3dcit_e": 0.0, "EX_fe3dhbzs_e": 0.0, "EX_fe3hox_e": 0.0, "EX_fe3hox_un_e": 0.0, "EX_fecrm_e": 0.0, "EX_fecrm_un_e": 0.0, "EX_feenter_e": 0.0, "EX_feoxam_e": 0.0, "EX_feoxam_un_e": 0.0, "EX_for_e": 0.0, "EX_fru_e": 0.0, "EX_frulys_e": 0.0, "EX_fruur_e": 0.0, "EX_fuc__L_e": 0.0, "EX_fum_e": 0.0, "EX_fusa_e": 0.0, "EX_g1p_e": 0.0, "EX_g3pc_e": 0.0, "EX_g3pe_e": 0.0, "EX_g3pg_e": 0.0, "EX_g3pi_e": 0.0, "EX_g3ps_e": 0.0, "EX_g6p_e": 0.0, "EX_gal_e": 0.0, "EX_gal_bD_e": 0.0, "EX_gal1p_e": 0.0, "EX_galct__D_e": 0.0, "EX_galctn__D_e": 0.0, "EX_galctn__L_e": 0.0, "EX_galt_e": 0.0, "EX_galur_e": 0.0, "EX_gam_e": 0.0, "EX_gam6p_e": 0.0, "EX_gbbtn_e": 0.0, "EX_gdp_e": 0.0, "EX_glc__D_e": -8.0, "EX_glcn_e": 0.0, "EX_glcr_e": 0.0, "EX_glcur_e": 0.0, "EX_glcur1p_e": 0.0, "EX_gln__L_e": 0.0, "EX_glu__L_e": 0.0, "EX_gly_e": 0.0, "EX_glyald_e": 0.0, "EX_glyb_e": 0.0, "EX_glyc_e": 0.0, "EX_glyc__R_e": 0.0, "EX_glyc2p_e": 0.0, "EX_glyc3p_e": 0.0, "EX_glyclt_e": 0.0, "EX_gmp_e": 0.0, "EX_gsn_e": 0.0, "EX_gthox_e": 0.0, "EX_gthrd_e": 0.0, "EX_gtp_ ...

# %%
# declarar funcao para contsruir dicionar e pintar no escher
def draw_escher(solution,escher_map):
    WT_sol1={}
    for r in model.reactions:

        # prints e break para debug
        #print(r, pfba_solution.fluxes[r.id])
        #break
        WT_sol1[r.id]=solution.fluxes[r.id]

    #para confirmar que esta correcto    
    #WT_sol1

    b = escher.Builder(reaction_data=WT_sol1, map_name=escher_map, local_host='https://escher.github.io')
    return b

#draw_escher(solution).display_in_notebook()

# %%
# moma sim

moma_sol_WT=cobra.flux_analysis.moma(model=model,solution=pfba_solution,linear=True)

# %%
moma_sol_WT
# Out:
# <Solution -0.000 at 0x1323547048>

# %%
moma_sol_WT.objective_value
# Out:
# -1.7258845262345277e-14

# %%
# verificar solucao a pata

error_sum=0
for r in model.reactions:
    
    # prints e break para debug
    #print(r, pfba_solution.fluxes[r.id])
    #break
    pfba_value=pfba_solution.fluxes[r.id]
    moma_value=moma_sol_WT.fluxes[r.id]
    #print(pfba_value, moma_value)
    error_sum = error_sum + (pfba_value-moma_value)**2
error_sum
# Out:
# 3.986849244148705e-26

# %%
#variavel global para comparar o error numerico
E_VALUE = 1e-7

#fold_percentage_change 0 is knockout
def force_flux(fold_percentage_change, target_reaction, reference_solution):
    # alterer percentagem de fluxo numa reaccao especifica
    # percentagem com variavel
    #fold_percentage_change=4
    # reaccao a mudarcomo variavel
    #target_reaction='AKGDH'
    # delcarar a reference solution
    #reference_solution=pfba_solution

    model_reaction = model.reactions.get_by_id(target_reaction)
    # processo de verificar o flux actual da target reaction (target flux) e fazer o incremento de flux (fold change)
    target_flux = reference_solution.fluxes[target_reaction]
    prev_lb = model.reactions.get_by_id(target_reaction).lower_bound
    prev_ub = model.reactions.get_by_id(target_reaction).upper_bound
    if fold_percentage_change == 0:
        model.reactions.get_by_id(target_reaction).lower_bound = 0 
        model.reactions.get_by_id(target_reaction).upper_bound = 0
    elif target_flux > 0:
        target_flux = target_flux + target_flux*fold_percentage_change
        model.reactions.get_by_id(target_reaction).lower_bound = target_flux
    else:
        target_flux = target_flux - target_flux*fold_percentage_change
        model.reactions.get_by_id(target_reaction).upper_bound = target_flux
    print('reference flux change',reference_solution.fluxes[target_reaction], '->',target_flux)
    
    print(model_reaction, model_reaction.lower_bound, model_reaction.upper_bound)
    # restringir a target reaction ao novo flux com a fold change
    #model.reactions.get_by_id(target_reaction).lower_bound = target_flux
    moma_sol=cobra.flux_analysis.moma(model=model,solution=reference_solution,linear=True)
    model.reactions.get_by_id(target_reaction).lower_bound = prev_lb
    model.reactions.get_by_id(target_reaction).upper_bound = prev_ub
    print('error',moma_sol.objective_value, 'biomass flux',moma_sol.fluxes.BIOMASS_Ec_iJO1366_WT_53p95M)
    
    # checkar todas as reaccoes que mudaram o luxo devido a esta mudanca

    fold_change_impact={}
    for r in model.reactions:
        ref_value=reference_solution.fluxes[r.id]
        moma_value=moma_sol.fluxes[r.id]
        #print((ref_value - moma_value)**2, E_VALUE)
        if (ref_value - moma_value)**2 > E_VALUE:
            fold_change_impact[r.id] = (ref_value, moma_value)
    return fold_change_impact, moma_sol, target_flux

#print(fold_change_impact)
#draw_escher(moma_sol).display_in_notebook()

# %%
# testar a funcao de force flux para uma reacao e fazer print de todos as mudancas
fold_change_impact, moma_sol, target_flux = force_flux(0.1, 'AKGDH', pfba_solution)
print(fold_change_impact)
# Out:
# reference flux change 3.1971759566572424 -> 3.5168935523229665
# AKGDH: akg_c + coa_c + nad_c --> co2_c + nadh_c + succoa_c 3.5168935523229665 1000.0
# error 9.36412931661071 biomass flux 0.7788834821724886
# {'BIOMASS_Ec_iJO1366_WT_53p95M': (0.7865875166015222, 0.7788834821724886), 'EX_co2_e': (15.832896802339356, 15.96077175043154), 'EX_g3pe_e': (0.0, 0.000741264216681272), 'EX_glc__D_e': (-8.0, -7.998813747330674), 'EX_h2s_e': (0.0, 0.0018893296993404418), 'EX_ins_e': (0.0, 0.0031528760900609853), 'EX_k_e': (-0.14606143595773666, -0.1446308738046094), 'EX_lys__L_e': (0.0, 0.002568894872292393), 'EX_nh4_e': (-8.26410790733264, -8.203321714641506), 'EX_o2_e': (-14.232453139698244, -14.389095098725079), 'EX_pi_e': (-0.7292814696669904, -0.7234078855702042), 'EX_succ_e': (0.0, 0.02824920095255179), 'ACACT1r': (0.24634741138684774, 0.24431141228004605), 'ACACT2r': (0.24634741138684774, 0.24431141228004605), 'ACACT3r': (0.24634741138684774, 0.24431141228004605), 'ACACT4r': (0.24634505162429793, 0.24430906535755362), 'ACACT5r': (0.24634505162429793, 0.24430906535755362), 'ACACT6r': (0.21428767738520288, 0.21225169111845854), 'ACACT7r': (0.20787620253738387, 0.20584021370262806), 'ACACT8r': (-0.03824860458226561, -0.037873988204119434), 'ACALD': (0.0, 0.12435808069542637), 'ACGK': (0.2575554969109028, 0.255084890109856), 'ACGS': (0.2575554969109028, 0.255084890109856), 'ACHBS': (0.2220583754617093, 0.21988348031818655), 'ACLS': (0.6682359856786237, 0.6616911156778527), 'ACOAD1f': (-0.24634741138684774, -0.24431141228004605), 'ACOAD2f': (-0.24634741138684774, -0.24431141228004605), 'ACOAD3f': (-0.24634741138684774, -0.24431141228004605), 'ACOAD4f': (-0.24634505162429793, -0.24430906535755362), 'ACOAD5f': (-0.24634505162429793, -0.24430906535755362), 'ACOAD6f': (-0.21428767738520288, -0.21225169111845854), 'ACOAD7f': (-0.13366324352106346, -0.13235411235860667), 'ACODA': (0.2575554969109028, 0.255084890109856), 'ACONTa': (4.053098016497122, 4.364484453923219), 'ACONTb': (4.053098016497122, 4.364484453923219), 'ACOTA': (-0.2575554969109028, -0.255084890109856), 'ACS': (0.0, 0.009179816696246457), 'ADK1': (1.993801921118157, 2.1223414031527867), 'ADK3': (0.0, 0.0022051719988076812), 'ADSL1r': (0.22839512449543414, 0.22615816565057223), 'ADSS': (0.22839512449543414, 0.22615816565057223), 'AGDC': (0.0, 0.0004249083148989141), 'AGPR': (-0.2575554969109028, -0.255084890109856), 'AICART': (0.41446712107262396, 0.41375791847922483), 'AKGDH': (3.1971759566572424, 3.5168935523229665), 'ALATA_L': (-0.43202926055580304, -0.4277978581658285), 'ALDD2y': (0.0, 0.011225510046433351), 'ANPRT': (0.043446374891968474, 0.043020850254315235), 'ANS': (0.043446374891968474, 0.043020850254315235), 'ARGSL': (0.2260809840216095, 0.22386669044601668), 'ARGSS': (0.2260809840216095, 0.22386669044601668), 'ASAD': (-0.8228822377925497, -0.9526394059683512), 'ASNS2': (0.18424396718860772, 0.18243943579622635), 'ASPCT': (0.251962859667866, 0.24969304311614313), 'ASPK': (0.8228822377925497, 0.9526394059683512), 'ASPTA': (-2.2421118683589265, -2.361516909759495), 'ATPPRT': (0.07241010042826972, 0.0717008978348706), 'CBMKr': (0.4780438436894755, 0.4735597335621598), 'CHORM': (0.2471749014543125, 0.24475400878743628), 'CHORS': (0.2925507755245045, 0.2896854602235207), 'CO2tex': (-15.832896802339356, -15.96077175043154), 'CO2tpp': (-15.832896802339356, -15.96077175043154), 'CS': (4.053098016497122, 4.364484453923219), 'CTECOAI7': (-0.07421295901632041, -0.07348610134402143), 'CTECOAI8': (-0.03824860458226561, -0.037873988204119434), 'CTPS2': (0.12224985865517542, 0.12124982876208024), 'CYSDS': (0.0, 0.001857542853286251), 'CYSTL': (0.12294756178240089, 0.12179533868916037), 'CYTBO3_4pp': (28.457835644209762, 28.77003141152269), 'DDPA': (0.2925507755245045, 0.2896854602235207), 'DHAD1': (0.6682359856786237, 0.6616911156778527), 'DHAD2': (0.2220583754617093, 0.21988348031818655), 'DHAPT': (0.5613189651714597, 0.5548003128558618), 'DHORD2': (0.251962859667866, 0.24969304311614313), 'DHORTS': (-0.251962859667866, -0.24969304311614313), 'DHQS': (0.2925507755245045, 0.2896854602235207), 'DHQTi': (0.2925507755245045, 0.2896854602235207), 'DRPA': (0.0, 0.00038775946088216126), 'ECOAH ...

# %%
#draw 
draw_escher(moma_sol,'map_v1').display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="ulgxfxqced"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"ulgxfxqced"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": {"DM_4crsol_c": 0.00017369101652446494, "DM_5drib_c": 0.00018170171633494648, "DM_aacald_c": 0.0, "DM_amob_c": 1.5577669643449772e-06, "DM_mththf_c": 0.001054027272246058, "DM_oxam_c": 0.0, "BIOMASS_Ec_iJO1366_WT_53p95M": 0.7788834821724886, "BIOMASS_Ec_iJO1366_core_53p95M": 0.0, "EX_12ppd__R_e": 0.0, "EX_12ppd__S_e": 0.0, "EX_14glucan_e": 0.0, "EX_15dap_e": 0.0, "EX_23camp_e": 0.0, "EX_23ccmp_e": 0.0, "EX_23cgmp_e": 0.0, "EX_23cump_e": 0.0, "EX_23dappa_e": 0.0, "EX_26dap__M_e": 0.0, "EX_2ddglcn_e": 0.0, "EX_34dhpac_e": 0.0, "EX_3amp_e": 0.0, "EX_3cmp_e": 0.0, "EX_3gmp_e": 0.0, "EX_3hcinnm_e": 0.0, "EX_3hpp_e": 0.0, "EX_3hpppn_e": 0.0, "EX_3ump_e": 0.0, "EX_4abut_e": 0.0, "EX_4hoxpacd_e": 0.0, "EX_5dglcn_e": 0.0, "EX_5mtr_e": 0.005304746211960665, "EX_LalaDglu_e": 0.0, "EX_LalaDgluMdap_e": 0.0, "EX_LalaDgluMdapDala_e": 0.0, "EX_LalaLglu_e": 0.0, "EX_ac_e": 0.0, "EX_acac_e": 0.0, "EX_acald_e": 0.0, "EX_acgal_e": 0.0, "EX_acgal1p_e": 0.0, "EX_acgam_e": 0.0, "EX_acgam1p_e": 0.0, "EX_acmana_e": 0.0, "EX_acmum_e": 0.0, "EX_acnam_e": 0.0, "EX_acolipa_e": 0.0, "EX_acser_e": 0.0, "EX_ade_e": 0.0, "EX_adn_e": 0.0, "EX_adocbl_e": 0.0, "EX_ag_e": 0.0, "EX_agm_e": 0.0, "EX_akg_e": 0.0, "EX_ala_B_e": 0.0, "EX_ala__D_e": 0.0, "EX_ala__L_e": 0.0, "EX_alaala_e": 0.0, "EX_all__D_e": 0.0, "EX_alltn_e": 0.0, "EX_amp_e": 0.0, "EX_anhgm_e": 0.0, "EX_arab__L_e": 0.0, "EX_arbt_e": 0.0, "EX_arbtn_e": 0.0, "EX_arbtn_fe3_e": 0.0, "EX_arg__L_e": 0.0, "EX_ascb__L_e": 0.0, "EX_asn__L_e": 0.0, "EX_aso3_e": 0.0, "EX_asp__L_e": 0.0, "EX_btn_e": 0.0, "EX_but_e": 0.0, "EX_butso3_e": 0.0, "EX_ca2_e": -0.0038570310037181633, "EX_cbi_e": 0.0, "EX_cbl1_e": -0.00017369101652446494, "EX_cd2_e": 0.0, "EX_cgly_e": 0.0, "EX_chol_e": 0.0, "EX_chtbs_e": 0.0, "EX_cit_e": 0.0, "EX_cl_e": -0.0038570310037181633, "EX_cm_e": 0.0, "EX_cmp_e": 0.0, "EX_co2_e": 15.96077175043154, "EX_cobalt2_e": -1.8693203572139728e-05, "EX_colipa_e": 6.279558463105281e-05, "EX_colipap_e": 0.0, "EX_cpgn_e": 0.0, "EX_cpgn_un_e": 0.0, "EX_crn_e": 0.0, "EX_crn__D_e": 0.0, "EX_csn_e": 0.0, "EX_cu_e": 0.0, "EX_cu2_e": -0.0005249674669842574, "EX_cyan_e": 0.0, "EX_cynt_e": 0.0, "EX_cys__D_e": 0.0, "EX_cys__L_e": 0.0, "EX_cytd_e": 0.0, "EX_dad_2_e": 0.0, "EX_damp_e": 0.0, "EX_dca_e": 0.0, "EX_dcmp_e": 0.0, "EX_dcyt_e": 0.0, "EX_ddca_e": 0.0, "EX_dgmp_e": 0.0, "EX_dgsn_e": 0.0, "EX_dha_e": 0.0, "EX_dimp_e": 0.0, "EX_din_e": 0.0, "EX_dms_e": 0.0, "EX_dmso_e": 0.0, "EX_dopa_e": 0.0, "EX_doxrbcn_e": 0.0, "EX_dtmp_e": 0.0, "EX_dump_e": 0.0, "EX_duri_e": 0.0, "EX_eca4colipa_e": 0.0, "EX_enlipa_e": 0.0, "EX_enter_e": 0.0, "EX_etha_e": 0.0, "EX_ethso3_e": 0.0, "EX_etoh_e": 0.0, "EX_f6p_e": 0.0, "EX_fald_e": 0.0, "EX_fe2_e": -0.012213344370271835, "EX_fe3_e": 0.0001196205425796068, "EX_fe3dcit_e": 0.0, "EX_fe3dhbzs_e": 0.0, "EX_fe3hox_e": 0.0, "EX_fe3hox_un_e": 0.0, "EX_fecrm_e": 0.0, "EX_fecrm_un_e": 0.0, "EX_feenter_e": 0.0, "EX_feoxam_e": 0.0, "EX_feoxam_un_e": 0.0, "EX_for_e": 0.0, "EX_fru_e": 0.0, "EX_frulys_e": 0.0, "EX_fruur_e": 0.0, "EX_fuc__L_e": 0.0, "EX_fum_e": 0.0, "EX_fusa_e": 0.0, "EX_g1p_e": 0.0, "EX_g3pc_e": 0.0, "EX_g3pe_e": 0.000741264216681272, "EX_g3pg_e": 0.0002767289166908833, "EX_g3pi_e": 0.0, "EX_g3ps_e": 0.0, "EX_g6p_e": 0.0, "EX_gal_e": 0.0, "EX_gal_bD_e": 0.0, "EX_gal1p_e": 0.0, "EX_galct__D_e": 0.0, "EX_galctn__D_e": 0.0, "EX_galctn__L_e": 0.0, "EX_galt_e": 0.0, "EX_galur_e": 0.0, "EX_gam_e": 0.0, "EX_gam6p_e": 0.0, "EX_gbbtn_e": 0.0, "EX_gdp_e": 0.0, "EX_glc__D_e": -7.998813747330674, "EX_glcn_e": 0.0, "EX_glcr_e": 0.0, "EX_glcur_e": 0.0, "EX_glcur1p_e": 0.0, "EX_gln__L_e": 0.0, "EX_glu__L_e": 0.0, "EX_gly_e": 0.0, "EX_glyald_e": 0.0, "EX_glyb_e": 0.0, "EX_glyc_e": 0.0, "EX_glyc__R_e": 0.0, "EX_glyc2p_e": 0.0, "EX_glyc3p_e": 0.0, "EX_glyclt_e": 0.0, "EX_gmp_e": 0. ...

# %%
# todos os fluxos que mudaram de 0 para qualquer coisa
for r in fold_change_impact:
    if fold_change_impact[r][0] == 0 and not fold_change_impact[r][1] == 0:
        print(r, fold_change_impact[r])
# Out:
# EX_g3pe_e (0.0, 0.000741264216681272)
# EX_h2s_e (0.0, 0.0018893296993404418)
# EX_ins_e (0.0, 0.0031528760900609853)
# EX_lys__L_e (0.0, 0.002568894872292393)
# EX_succ_e (0.0, 0.02824920095255179)
# ACALD (0.0, 0.12435808069542637)
# ACS (0.0, 0.009179816696246457)
# ADK3 (0.0, 0.0022051719988076812)
# AGDC (0.0, 0.0004249083148989141)
# ALDD2y (0.0, 0.011225510046433351)
# CYSDS (0.0, 0.001857542853286251)
# DRPA (0.0, 0.00038775946088216126)
# EDA (0.0, 0.08675339336795762)
# EDD (0.0, 0.08675339336795762)
# FACOAL160t2pp (0.0, 0.0009345147843106277)
# FACOAL161t2pp (0.0, 0.0007268551042875077)
# FACOAL181t2pp (0.0, 0.0003746163781461753)
# FTHFLi (0.0, 0.22633507810100453)
# G3PEtex (0.0, -0.000741264216681272)
# GLCP (0.0, 0.0011878619565093979)
# GLUSy (0.0, 0.006165102191604983)
# GLXCL (0.0, 0.0003473820330489469)
# GLYCK2 (0.0, 0.0003473820330489469)
# H2St1pp (0.0, 0.0018893296993404418)
# H2Stex (0.0, -0.0018893296993404418)
# INSt2pp_copy2 (0.0, -0.0031528760900609853)
# INStex (0.0, -0.0031528760900609853)
# LPLIPAL1E160pp (0.0, 0.0003402409765238326)
# LYSt3pp (0.0, 0.002568894872292393)
# LYStex (0.0, -0.002568894872292393)
# MDH2 (0.0, 0.02404888825331808)
# NTD11 (0.0, 0.0031528760900609853)
# NTPP2 (0.0, 0.001625119838598199)
# NTPP8 (0.0, 0.002079367684614268)
# P5CD (0.0, 0.0016548111872875526)
# PFL (0.0, 0.22635569409713716)
# PLIPA2E160pp (0.0, 0.0003402409765238326)
# PPM2 (0.0, 0.00038775946088216126)
# PPPGO (0.0, 0.0003473820330489299)
# PPS (0.0, 0.13069230511947127)
# SERD_L (0.0, 0.18561892961298312)
# SUCCt3pp (0.0, 0.02824920095255179)
# SUCCtex (0.0, -0.02824920095255179)
# TALA (0.0, -0.07656798617778027)
# THD2pp (0.0, 0.6140266326355404)
# THRA (0.0, 0.1351958312809775)
# TRSARr (0.0, 0.0003473820330489469)

# %%
# a solucao do moma, o erro. a reaccao ou fold change, o erro maior diz que tem maior impacto
moma_sol.objective_value
# Out:
# 9.36412931661071

# %%
# correr a funcao para varias reaccoes ao mesmo tempo.
# percursossores para valien e leucina
reactions_array = [
                   'DHAD1', #test pyr to 3mob
                   'KARA1', #test pyr to 3mob
                   'ACLS',  #test pyr to 3mob
                   'VALtex','VALt2rpp','LEUtex','LEUt2rpp','ILEtex','ILEt2rpp','CADVtpp','LYStex','DAPabcpp','26DAHtex', #transport
                   'VPAMTr','VALTA','LEUTAi','OMCDC','IPMD','IPPMIa','IPPMIb','IPPS','MOHMT', #3mob fork
                   'OAADC','ASPTA','ASP1DC','ASPK','ASAD', #pyr to aspsa_c
                   'ILETA','DHAD2','KARA2','ACHBS','OBTFL','THRD_L','THRS','HSK','HSDy', #ile_L_p to aspsa_c
                   'DHDPS','DHDPRy','THDPS','SDPTA','SDPDS','DAPE','DAPDC','LADGMDH','UAAGDS', #aspsa_c to ugmd/lys_L_c
                  ]
folds = [
          0,
          -0.4,-0.3,-0.2,-0.1,
          0.1, 0.2, 0.3, 0.4
        ]
reaction_moma_error = {}
all_solutions = {}
for r in reactions_array:
    reaction_moma_error[r] = {}
    all_solutions[r] = {}
    for f in folds:
        fold_change_impact, moma_sol, target_flux = force_flux(f, r, pfba_solution)
        reaction_moma_error[r][f] = moma_sol.objective_value
        all_solutions[r][f] = moma_sol
    
#plt.plot(reaction_moma_error)
# Out:
# reference flux change 0.6682359856786237 -> 0.6682359856786237
# DHAD1: 23dhmb_c --> 3mob_c + h2o_c 0 0
# error 85.78826214945029 biomass flux 0.0
# reference flux change 0.6682359856786237 -> 0.4009415914071742
# DHAD1: 23dhmb_c --> 3mob_c + h2o_c 0.4009415914071742 1000.0
# error 7.323990109478933e-14 biomass flux 0.786587516601523
# reference flux change 0.6682359856786237 -> 0.46776518997503663
# DHAD1: 23dhmb_c --> 3mob_c + h2o_c 0.46776518997503663 1000.0
# error -3.8084193935165917e-14 biomass flux 0.7865875166015225
# reference flux change 0.6682359856786237 -> 0.534588788542899
# DHAD1: 23dhmb_c --> 3mob_c + h2o_c 0.534588788542899 1000.0
# error -1.3904602504827205e-13 biomass flux 0.7865875166015209
# reference flux change 0.6682359856786237 -> 0.6014123871107614
# DHAD1: 23dhmb_c --> 3mob_c + h2o_c 0.6014123871107614 1000.0
# error 3.8710207160346026e-13 biomass flux 0.7865875166015237
# reference flux change 0.6682359856786237 -> 0.7350595842464861
# DHAD1: 23dhmb_c --> 3mob_c + h2o_c 0.7350595842464861 1000.0
# error 2.4180945699040435 biomass flux 0.7750794269176765
# reference flux change 0.6682359856786237 -> 0.8018831828143484
# DHAD1: 23dhmb_c --> 3mob_c + h2o_c 0.8018831828143484 1000.0
# error 4.836890798888754 biomass flux 0.7635713372338331
# reference flux change 0.6682359856786237 -> 0.8687067813822109
# DHAD1: 23dhmb_c --> 3mob_c + h2o_c 0.8687067813822109 1000.0
# error 7.255687016365066 biomass flux 0.7520632475499897
# reference flux change 0.6682359856786237 -> 0.9355303799500733
# DHAD1: 23dhmb_c --> 3mob_c + h2o_c 0.9355303799500733 1000.0
# error 9.674483233841645 biomass flux 0.7405551578661478
# reference flux change -0.6682359856786237 -> -0.6682359856786237
# KARA1: 23dhmb_c + nadp_c --> alac__S_c + h_c + nadph_c 0 0
# error 85.78826214944962 biomass flux 0.0
# reference flux change -0.6682359856786237 -> -0.9355303799500733
# KARA1: 23dhmb_c + nadp_c <-- alac__S_c + h_c + nadph_c -1000.0 -0.9355303799500733
# error 9.674483233841713 biomass flux 0.7405551578661422
# reference flux change -0.6682359856786237 -> -0.8687067813822109
# KARA1: 23dhmb_c + nadp_c <-- alac__S_c + h_c + nadph_c -1000.0 -0.8687067813822109
# error 7.255685842540004 biomass flux 0.7520632475499889
# reference flux change -0.6682359856786237 -> -0.8018831828143484
# KARA1: 23dhmb_c + nadp_c <-- alac__S_c + h_c + nadph_c -1000.0 -0.8018831828143484
# error 4.836889786176864 biomass flux 0.7635713372338319
# reference flux change -0.6682359856786237 -> -0.7350595842464861
# KARA1: 23dhmb_c + nadp_c <-- alac__S_c + h_c + nadph_c -1000.0 -0.7350595842464861
# error 2.4180945468880433 biomass flux 0.7750794269176781
# reference flux change -0.6682359856786237 -> -0.6014123871107614
# KARA1: 23dhmb_c + nadp_c <-- alac__S_c + h_c + nadph_c -1000.0 -0.6014123871107614
# error -7.595497089343124e-14 biomass flux 0.7865875166015234
# reference flux change -0.6682359856786237 -> -0.534588788542899
# KARA1: 23dhmb_c + nadp_c <-- alac__S_c + h_c + nadph_c -1000.0 -0.534588788542899
# error -9.407059751383429e-14 biomass flux 0.7865875166015215
# reference flux change -0.6682359856786237 -> -0.46776518997503663
# KARA1: 23dhmb_c + nadp_c <-- alac__S_c + h_c + nadph_c -1000.0 -0.46776518997503663
# error 6.839728394265986e-14 biomass flux 0.7865875166015222
# reference flux change -0.6682359856786237 -> -0.4009415914071742
# KARA1: 23dhmb_c + nadp_c <-- alac__S_c + h_c + nadph_c -1000.0 -0.4009415914071742
# error 1.1908701183122184e-13 biomass flux 0.7865875166015203
# reference flux change 0.6682359856786237 -> 0.6682359856786237
# ACLS: h_c + 2.0 pyr_c --> alac__S_c + co2_c 0 0
# error 85.78826214945009 biomass flux 0.0
# reference flux change 0.6682359856786237 -> 0.4009415914071742
# ACLS: h_c + 2.0 pyr_c --> alac__S_c + co2_c 0.4009415914071742 1000.0
# error -3.655119778949614e-14 biomass flux 0.7865875166015224
# reference flux change 0.6682359856786237 -> 0.46776518997503663
# ACLS: h_c + 2.0 pyr_c --> alac__S_c + co2_c 0.46776518997503663 1000.0
# error 1.1079586064459646e-14 biomass flux 0.7865875166015224
# reference flux change 0.6682359856786237 -> 0.534588788542899
# ACLS: h_c + 2.0 pyr_c --> alac__S_c + co2_c 0.534588788542899 1000.0
# error 9.298288092652959e-14 biomass flux 0.7865875166015206
# reference flux change 0.6682359856786237 -> 0.6014123871107614
# ACLS: h_c + 2.0 pyr_c --> alac__S_c + co2_c 0.6014123871107614 1000.0
# error -2.9049534144199137e-14 biomass flux 0.7865875166015193
# reference flux change 0.6682359856786237 -> 0.7350595842464861
# ACLS: h_c + 2.0 pyr_c --> alac__S_c + co2_c 0.7350595842464861 1000.0
# error 2.418094546888218 biomass flux 0.775079426917679
# reference flux change 0.6682359856786237 -> 0.8018831828143484
# ACLS: h_c + 2.0 pyr_c --> alac__S_c + co2_c 0.8018831828143484 1000.0
# error 4.836890338565485 biomass flux 0.7635713372338373
# reference flux change 0.6682359856786237 -> 0.8687067813822109
# ACLS: h_c + 2.0 pyr_c --> alac__S_c + co2_c 0.8687067813822109 1000.0
# error 7.255687016365203 biomass flux 0.7520632475499874
# reference flux change 0.6682359856786237 -> 0.9355303799500733
# ACLS: h_c + 2.0 pyr_c --> alac__S_c + co2_c 0.9355303799500733 1000.0
# error 9.674483233841906 biomass flux 0.7405551578661412
# reference flux change 0.0 -> 0.0
# VALtex: val__L_e --> val__L_p 0 0
# error -6.450054629816747e-14 biomass flux 0.7865875166015222
# reference flux change 0.0 -> 0.0
# VALtex: val__L_e <-- val__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALtex: val__L_e <-- val__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALtex: val__L_e <-- val__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALtex: val__L_e <-- val__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALtex: val__L_e <-- val__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALtex: val__L_e <-- val__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALtex: val__L_e <-- val__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALtex: val__L_e <-- val__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALt2rpp: h_p + val__L_p --> h_c + val__L_c 0 0
# error 1.4790984528588864e-14 biomass flux 0.786587516601523
# reference flux change 0.0 -> 0.0
# VALt2rpp: h_p + val__L_p <-- h_c + val__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALt2rpp: h_p + val__L_p <-- h_c + val__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALt2rpp: h_p + val__L_p <-- h_c + val__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALt2rpp: h_p + val__L_p <-- h_c + val__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALt2rpp: h_p + val__L_p <-- h_c + val__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALt2rpp: h_p + val__L_p <-- h_c + val__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALt2rpp: h_p + val__L_p <-- h_c + val__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VALt2rpp: h_p + val__L_p <-- h_c + val__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUtex: leu__L_e --> leu__L_p 0 0
# error -4.6555317792392834e-14 biomass flux 0.7865875166015224
# reference flux change 0.0 -> 0.0
# LEUtex: leu__L_e <-- leu__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUtex: leu__L_e <-- leu__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUtex: leu__L_e <-- leu__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUtex: leu__L_e <-- leu__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUtex: leu__L_e <-- leu__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUtex: leu__L_e <-- leu__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUtex: leu__L_e <-- leu__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUtex: leu__L_e <-- leu__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUt2rpp: h_p + leu__L_p --> h_c + leu__L_c 0 0
# error 2.8130764559400696e-14 biomass flux 0.7865875166015224
# reference flux change 0.0 -> 0.0
# LEUt2rpp: h_p + leu__L_p <-- h_c + leu__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUt2rpp: h_p + leu__L_p <-- h_c + leu__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUt2rpp: h_p + leu__L_p <-- h_c + leu__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUt2rpp: h_p + leu__L_p <-- h_c + leu__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUt2rpp: h_p + leu__L_p <-- h_c + leu__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUt2rpp: h_p + leu__L_p <-- h_c + leu__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUt2rpp: h_p + leu__L_p <-- h_c + leu__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LEUt2rpp: h_p + leu__L_p <-- h_c + leu__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEtex: ile__L_e --> ile__L_p 0 0
# error -1.2580032595320703e-13 biomass flux 0.7865875166015208
# reference flux change 0.0 -> 0.0
# ILEtex: ile__L_e <-- ile__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEtex: ile__L_e <-- ile__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEtex: ile__L_e <-- ile__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEtex: ile__L_e <-- ile__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEtex: ile__L_e <-- ile__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEtex: ile__L_e <-- ile__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEtex: ile__L_e <-- ile__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEtex: ile__L_e <-- ile__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEt2rpp: h_p + ile__L_p --> h_c + ile__L_c 0 0
# error -5.5756056590424867e-14 biomass flux 0.7865875166015205
# reference flux change 0.0 -> 0.0
# ILEt2rpp: h_p + ile__L_p <-- h_c + ile__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEt2rpp: h_p + ile__L_p <-- h_c + ile__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEt2rpp: h_p + ile__L_p <-- h_c + ile__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEt2rpp: h_p + ile__L_p <-- h_c + ile__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEt2rpp: h_p + ile__L_p <-- h_c + ile__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEt2rpp: h_p + ile__L_p <-- h_c + ile__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEt2rpp: h_p + ile__L_p <-- h_c + ile__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# ILEt2rpp: h_p + ile__L_p <-- h_c + ile__L_c -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# CADVtpp: 15dap_c + h_p + lys__L_p --> 15dap_p + h_c + lys__L_c 0 0
# error 4.737003989061933e-14 biomass flux 0.7865875166015225
# reference flux change 0.0 -> 0.0
# CADVtpp: 15dap_c + h_p + lys__L_p --> 15dap_p + h_c + lys__L_c 0.0 0.0
# error 4.737003989061933e-14 biomass flux 0.7865875166015225
# reference flux change 0.0 -> 0.0
# CADVtpp: 15dap_c + h_p + lys__L_p --> 15dap_p + h_c + lys__L_c 0.0 0.0
# error 4.737003989061933e-14 biomass flux 0.7865875166015225
# reference flux change 0.0 -> 0.0
# CADVtpp: 15dap_c + h_p + lys__L_p --> 15dap_p + h_c + lys__L_c 0.0 0.0
# error 4.737003989061933e-14 biomass flux 0.7865875166015225
# reference flux change 0.0 -> 0.0
# CADVtpp: 15dap_c + h_p + lys__L_p --> 15dap_p + h_c + lys__L_c 0.0 0.0
# error 4.737003989061933e-14 biomass flux 0.7865875166015225
# reference flux change 0.0 -> 0.0
# CADVtpp: 15dap_c + h_p + lys__L_p --> 15dap_p + h_c + lys__L_c 0.0 0.0
# error 4.737003989061933e-14 biomass flux 0.7865875166015225
# reference flux change 0.0 -> 0.0
# CADVtpp: 15dap_c + h_p + lys__L_p --> 15dap_p + h_c + lys__L_c 0.0 0.0
# error 4.737003989061933e-14 biomass flux 0.7865875166015225
# reference flux change 0.0 -> 0.0
# CADVtpp: 15dap_c + h_p + lys__L_p --> 15dap_p + h_c + lys__L_c 0.0 0.0
# error 4.737003989061933e-14 biomass flux 0.7865875166015225
# reference flux change 0.0 -> 0.0
# CADVtpp: 15dap_c + h_p + lys__L_p --> 15dap_p + h_c + lys__L_c 0.0 0.0
# error 4.737003989061933e-14 biomass flux 0.7865875166015225
# reference flux change 0.0 -> 0.0
# LYStex: lys__L_e --> lys__L_p 0 0
# error -1.260581053448307e-14 biomass flux 0.786587516601521
# reference flux change 0.0 -> 0.0
# LYStex: lys__L_e <-- lys__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LYStex: lys__L_e <-- lys__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LYStex: lys__L_e <-- lys__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LYStex: lys__L_e <-- lys__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LYStex: lys__L_e <-- lys__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LYStex: lys__L_e <-- lys__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LYStex: lys__L_e <-- lys__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# LYStex: lys__L_e <-- lys__L_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# DAPabcpp: 26dap__M_p + atp_c + h2o_c --> 26dap__M_c + adp_c + h_c + pi_c 0 0
# error 3.192971722707115e-14 biomass flux 0.7865875166015222
# reference flux change 0.0 -> 0.0
# DAPabcpp: 26dap__M_p + atp_c + h2o_c --> 26dap__M_c + adp_c + h_c + pi_c 0.0 0.0
# error 3.192971722707115e-14 biomass flux 0.7865875166015222
# reference flux change 0.0 -> 0.0
# DAPabcpp: 26dap__M_p + atp_c + h2o_c --> 26dap__M_c + adp_c + h_c + pi_c 0.0 0.0
# error 3.192971722707115e-14 biomass flux 0.7865875166015222
# reference flux change 0.0 -> 0.0
# DAPabcpp: 26dap__M_p + atp_c + h2o_c --> 26dap__M_c + adp_c + h_c + pi_c 0.0 0.0
# error 3.192971722707115e-14 biomass flux 0.7865875166015222
# reference flux change 0.0 -> 0.0
# DAPabcpp: 26dap__M_p + atp_c + h2o_c --> 26dap__M_c + adp_c + h_c + pi_c 0.0 0.0
# error 3.192971722707115e-14 biomass flux 0.7865875166015222
# reference flux change 0.0 -> 0.0
# DAPabcpp: 26dap__M_p + atp_c + h2o_c --> 26dap__M_c + adp_c + h_c + pi_c 0.0 0.0
# error 3.192971722707115e-14 biomass flux 0.7865875166015222
# reference flux change 0.0 -> 0.0
# DAPabcpp: 26dap__M_p + atp_c + h2o_c --> 26dap__M_c + adp_c + h_c + pi_c 0.0 0.0
# error 3.192971722707115e-14 biomass flux 0.7865875166015222
# reference flux change 0.0 -> 0.0
# DAPabcpp: 26dap__M_p + atp_c + h2o_c --> 26dap__M_c + adp_c + h_c + pi_c 0.0 0.0
# error 3.192971722707115e-14 biomass flux 0.7865875166015222
# reference flux change 0.0 -> 0.0
# DAPabcpp: 26dap__M_p + atp_c + h2o_c --> 26dap__M_c + adp_c + h_c + pi_c 0.0 0.0
# error 3.192971722707115e-14 biomass flux 0.7865875166015222
# reference flux change 0.0 -> 0.0
# 26DAHtex: 26dap__M_e --> 26dap__M_p 0 0
# error 1.642153226817244e-13 biomass flux 0.7865875166015219
# reference flux change 0.0 -> 0.0
# 26DAHtex: 26dap__M_e <-- 26dap__M_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# 26DAHtex: 26dap__M_e <-- 26dap__M_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# 26DAHtex: 26dap__M_e <-- 26dap__M_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# 26DAHtex: 26dap__M_e <-- 26dap__M_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# 26DAHtex: 26dap__M_e <-- 26dap__M_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# 26DAHtex: 26dap__M_e <-- 26dap__M_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# 26DAHtex: 26dap__M_e <-- 26dap__M_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# 26DAHtex: 26dap__M_e <-- 26dap__M_p -1000.0 0.0
# error -1.7258845262345277e-14 biomass flux 0.786587516601522
# reference flux change 0.0 -> 0.0
# VPAMTr: 3mob_c + ala__L_c --> pyr_c + val__L_c 0 0
# error -2.4477847668452057e-14 biomass flux 0.7865875166015236
# reference flux change 0.0 -> 0.0
# VPAMTr: 3mob_c + ala__L_c <-- pyr_c + val__L_c -1000.0 0.0
# error -2.7367565537810117e-16 biomass flux 0.786587516601521
# reference flux change 0.0 -> 0.0
# VPAMTr: 3mob_c + ala__L_c <-- pyr_c + val__L_c -1000.0 0.0
# error -2.7367565537810117e-16 biomass flux 0.786587516601521
# reference flux change 0.0 -> 0.0
# VPAMTr: 3mob_c + ala__L_c <-- pyr_c + val__L_c -1000.0 0.0
# error -2.7367565537810117e-16 biomass flux 0.786587516601521
# reference flux change 0.0 -> 0.0
# VPAMTr: 3mob_c + ala__L_c <-- pyr_c + val__L_c -1000.0 0.0
# error -2.7367565537810117e-16 biomass flux 0.786587516601521
# reference flux change 0.0 -> 0.0
# VPAMTr: 3mob_c + ala__L_c <-- pyr_c + val__L_c -1000.0 0.0
# error -2.7367565537810117e-16 biomass flux 0.786587516601521
# reference flux change 0.0 -> 0.0
# VPAMTr: 3mob_c + ala__L_c <-- pyr_c + val__L_c -1000.0 0.0
# error -2.7367565537810117e-16 biomass flux 0.786587516601521
# reference flux change 0.0 -> 0.0
# VPAMTr: 3mob_c + ala__L_c <-- pyr_c + val__L_c -1000.0 0.0
# error -2.7367565537810117e-16 biomass flux 0.786587516601521
# reference flux change 0.0 -> 0.0
# VPAMTr: 3mob_c + ala__L_c <-- pyr_c + val__L_c -1000.0 0.0
# error -2.7367565537810117e-16 biomass flux 0.786587516601521
# reference flux change -0.32343220142628026 -> -0.32343220142628026
# VALTA: akg_c + val__L_c --> 3mob_c + glu__L_c 0 0
# error 0.9702966042788523 biomass flux 0.7865875166015194
# reference flux change -0.32343220142628026 -> -0.45280508199679237
# VALTA: akg_c + val__L_c <-- 3mob_c + glu__L_c -1000.0 -0.45280508199679237
# error 0.3881186417116031 biomass flux 0.7865875166015214
# reference flux change -0.32343220142628026 -> -0.42046186185416434
# VALTA: akg_c + val__L_c <-- 3mob_c + glu__L_c -1000.0 -0.42046186185416434
# error 0.29108898128350263 biomass flux 0.7865875166015242
# reference flux change -0.32343220142628026 -> -0.3881186417115363
# VALTA: akg_c + val__L_c <-- 3mob_c + glu__L_c -1000.0 -0.3881186417115363
# error 0.1940593208557546 biomass flux 0.786587516601522
# reference flux change -0.32343220142628026 -> -0.3557754215689083
# VALTA: akg_c + val__L_c <-- 3mob_c + glu__L_c -1000.0 -0.3557754215689083
# error 0.09702966042785936 biomass flux 0.7865875166015236
# reference flux change -0.32343220142628026 -> -0.29108898128365224
# VALTA: akg_c + val__L_c <-- 3mob_c + glu__L_c -1000.0 -0.29108898128365224
# error -3.614473279518549e-14 biomass flux 0.7865875166015217
# reference flux change -0.32343220142628026 -> -0.2587457611410242
# VALTA: akg_c + val__L_c <-- 3mob_c + glu__L_c -1000.0 -0.2587457611410242
# error -1.2197816644902118e-13 biomass flux 0.7865875166015204
# reference flux change -0.32343220142628026 -> -0.22640254099839618
# VALTA: akg_c + val__L_c <-- 3mob_c + glu__L_c -1000.0 -0.22640254099839618
# error -1.1414929083992003e-13 biomass flux 0.7865875166015225
# reference flux change -0.32343220142628026 -> -0.19405932085576816
# VALTA: akg_c + val__L_c <-- 3mob_c + glu__L_c -1000.0 -0.19405932085576816
# error -1.4017241838810236e-14 biomass flux 0.786587516601521
# reference flux change 0.34435070984278116 -> 0.34435070984278116
# LEUTAi: 4mop_c + glu__L_c --> akg_c + leu__L_c 0 0
# error 82.76247264038996 biomass flux 0.0
# reference flux change 0.34435070984278116 -> 0.2066104259056687
# LEUTAi: 4mop_c + glu__L_c --> akg_c + leu__L_c 0.2066104259056687 1000.0
# error 3.2033253054994124e-14 biomass flux 0.7865875166015229
# reference flux change 0.34435070984278116 -> 0.2410454968899468
# LEUTAi: 4mop_c + glu__L_c --> akg_c + leu__L_c 0.2410454968899468 1000.0
# error -1.9819146900068334e-14 biomass flux 0.7865875166015222
# reference flux change 0.34435070984278116 -> 0.2754805678742249
# LEUTAi: 4mop_c + glu__L_c --> akg_c + leu__L_c 0.2754805678742249 1000.0
# error -4.840812055692346e-14 biomass flux 0.786587516601522
# reference flux change 0.34435070984278116 -> 0.30991563885850304
# LEUTAi: 4mop_c + glu__L_c --> akg_c + leu__L_c 0.30991563885850304 1000.0
# error 8.051088353950205e-14 biomass flux 0.7865875166015227
# reference flux change 0.34435070984278116 -> 0.37878578082705927
# LEUTAi: 4mop_c + glu__L_c --> akg_c + leu__L_c 0.37878578082705927 1000.0
# error 1.6441880468055015 biomass flux 0.7793450778067308
# reference flux change 0.34435070984278116 -> 0.4132208518113374
# LEUTAi: 4mop_c + glu__L_c --> akg_c + leu__L_c 0.4132208518113374 1000.0
# error 3.2887269116437903 biomass flux 0.7721026390119496
# reference flux change 0.34435070984278116 -> 0.4476559227956155
# LEUTAi: 4mop_c + glu__L_c --> akg_c + leu__L_c 0.4476559227956155 1000.0
# error 4.933265841663367 biomass flux 0.7648602002171696
# reference flux change 0.34435070984278116 -> 0.4820909937798936
# LEUTAi: 4mop_c + glu__L_c --> akg_c + leu__L_c 0.4820909937798936 1000.0
# error 6.577804728228622 biomass flux 0.7576177614223882
# reference flux change 0.34435070984278116 -> 0.34435070984278116
# OMCDC: 3c4mop_c + h_c --> 4mop_c + co2_c 0 0
# error 82.76247264038993 biomass flux 0.0
# reference flux change 0.34435070984278116 -> 0.2066104259056687
# OMCDC: 3c4mop_c + h_c --> 4mop_c + co2_c 0.2066104259056687 1000.0
# error 5.022954460389232e-14 biomass flux 0.7865875166015234
# reference flux change 0.34435070984278116 -> 0.2410454968899468
# OMCDC: 3c4mop_c + h_c --> 4mop_c + co2_c 0.2410454968899468 1000.0
# error 3.1584575973605654e-15 biomass flux 0.7865875166015222
# reference flux change 0.34435070984278116 -> 0.2754805678742249
# OMCDC: 3c4mop_c + h_c --> 4mop_c + co2_c 0.2754805678742249 1000.0
# error 1.1943262123330969e-15 biomass flux 0.7865875166015223
# reference flux change 0.34435070984278116 -> 0.30991563885850304
# OMCDC: 3c4mop_c + h_c --> 4mop_c + co2_c 0.30991563885850304 1000.0
# error 7.895981629981781e-15 biomass flux 0.786587516601523
# reference flux change 0.34435070984278116 -> 0.37878578082705927
# OMCDC: 3c4mop_c + h_c --> 4mop_c + co2_c 0.37878578082705927 1000.0
# error 1.644188068532932 biomass flux 0.7793450778067453
# reference flux change 0.34435070984278116 -> 0.4132208518113374
# OMCDC: 3c4mop_c + h_c --> 4mop_c + co2_c 0.4132208518113374 1000.0
# error 3.2887269550980673 biomass flux 0.7721026390119464
# reference flux change 0.34435070984278116 -> 0.4476559227956155
# OMCDC: 3c4mop_c + h_c --> 4mop_c + co2_c 0.4476559227956155 1000.0
# error 4.933265841663276 biomass flux 0.7648602002171678
# reference flux change 0.34435070984278116 -> 0.4820909937798936
# OMCDC: 3c4mop_c + h_c --> 4mop_c + co2_c 0.4820909937798936 1000.0
# error 6.577804728228937 biomass flux 0.7576177614223839
# reference flux change 0.34435070984278116 -> 0.34435070984278116
# IPMD: 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c 0 0
# error 82.76247264038993 biomass flux 0.0
# reference flux change 0.34435070984278116 -> 0.2066104259056687
# IPMD: 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c 0.2066104259056687 1000.0
# error -2.4106309293661237e-13 biomass flux 0.7865875166015268
# reference flux change 0.34435070984278116 -> 0.2410454968899468
# IPMD: 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c 0.2410454968899468 1000.0
# error -1.4189524101200078e-13 biomass flux 0.7865875166015212
# reference flux change 0.34435070984278116 -> 0.2754805678742249
# IPMD: 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c 0.2754805678742249 1000.0
# error -4.738358619203796e-14 biomass flux 0.7865875166015215
# reference flux change 0.34435070984278116 -> 0.30991563885850304
# IPMD: 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c 0.30991563885850304 1000.0
# error 4.85532739349825e-14 biomass flux 0.7865875166015226
# reference flux change 0.34435070984278116 -> 0.37878578082705927
# IPMD: 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c 0.37878578082705927 1000.0
# error 1.6441880685331784 biomass flux 0.7793450778067329
# reference flux change 0.34435070984278116 -> 0.4132208518113374
# IPMD: 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c 0.4132208518113374 1000.0
# error 3.288726955098543 biomass flux 0.7721026390119533
# reference flux change 0.34435070984278116 -> 0.4476559227956155
# IPMD: 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c 0.4476559227956155 1000.0
# error 4.933265102934208 biomass flux 0.7648602002171673
# reference flux change 0.34435070984278116 -> 0.4820909937798936
# IPMD: 3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c 0.4820909937798936 1000.0
# error 6.577804728229125 biomass flux 0.7576177614224043
# reference flux change -0.34435070984278116 -> -0.34435070984278116
# IPPMIa: 3c2hmp_c --> 2ippm_c + h2o_c 0 0
# error 82.7624726403902 biomass flux 0.0
# reference flux change -0.34435070984278116 -> -0.4820909937798936
# IPPMIa: 3c2hmp_c <-- 2ippm_c + h2o_c -1000.0 -0.4820909937798936
# error 6.57780472822839 biomass flux 0.7576177614223792
# reference flux change -0.34435070984278116 -> -0.4476559227956155
# IPPMIa: 3c2hmp_c <-- 2ippm_c + h2o_c -1000.0 -0.4476559227956155
# error 4.933265841663309 biomass flux 0.7648602002171712
# reference flux change -0.34435070984278116 -> -0.4132208518113374
# IPPMIa: 3c2hmp_c <-- 2ippm_c + h2o_c -1000.0 -0.4132208518113374
# error 3.2887269550978386 biomass flux 0.7721026390119438
# reference flux change -0.34435070984278116 -> -0.37878578082705927
# IPPMIa: 3c2hmp_c <-- 2ippm_c + h2o_c -1000.0 -0.37878578082705927
# error 1.6441880685325443 biomass flux 0.7793450778067298
# reference flux change -0.34435070984278116 -> -0.30991563885850304
# IPPMIa: 3c2hmp_c <-- 2ippm_c + h2o_c -1000.0 -0.30991563885850304
# error -4.513472961215064e-15 biomass flux 0.786587516601522
# reference flux change -0.34435070984278116 -> -0.2754805678742249
# IPPMIa: 3c2hmp_c <-- 2ippm_c + h2o_c -1000.0 -0.2754805678742249
# error -3.565491751025054e-14 biomass flux 0.7865875166015222
# reference flux change -0.34435070984278116 -> -0.2410454968899468
# IPPMIa: 3c2hmp_c <-- 2ippm_c + h2o_c -1000.0 -0.2410454968899468
# error -3.96436539120486e-14 biomass flux 0.7865875166015222
# reference flux change -0.34435070984278116 -> -0.2066104259056687
# IPPMIa: 3c2hmp_c <-- 2ippm_c + h2o_c -1000.0 -0.2066104259056687
# error -5.3173396433529665e-14 biomass flux 0.7865875166015222
# reference flux change -0.34435070984278116 -> -0.34435070984278116
# IPPMIb: 2ippm_c + h2o_c --> 3c3hmp_c 0 0
# error 82.76247264039024 biomass flux 0.0
# reference flux change -0.34435070984278116 -> -0.4820909937798936
# IPPMIb: 2ippm_c + h2o_c <-- 3c3hmp_c -1000.0 -0.4820909937798936
# error 6.577804554409421 biomass flux 0.7576177614223817
# reference flux change -0.34435070984278116 -> -0.4476559227956155
# IPPMIb: 2ippm_c + h2o_c <-- 3c3hmp_c -1000.0 -0.4476559227956155
# error 4.933265689572258 biomass flux 0.7648602002171674
# reference flux change -0.34435070984278116 -> -0.4132208518113374
# IPPMIb: 2ippm_c + h2o_c <-- 3c3hmp_c -1000.0 -0.4132208518113374
# error 3.2887267667946993 biomass flux 0.7721026390119562
# reference flux change -0.34435070984278116 -> -0.37878578082705927
# IPPMIb: 2ippm_c + h2o_c <-- 3c3hmp_c -1000.0 -0.37878578082705927
# error 1.6441878729873798 biomass flux 0.7793450778067325
# reference flux change -0.34435070984278116 -> -0.30991563885850304
# IPPMIb: 2ippm_c + h2o_c <-- 3c3hmp_c -1000.0 -0.30991563885850304
# error 1.1921292492424454e-13 biomass flux 0.7865875166015233
# reference flux change -0.34435070984278116 -> -0.2754805678742249
# IPPMIb: 2ippm_c + h2o_c <-- 3c3hmp_c -1000.0 -0.2754805678742249
# error -1.841162664261567e-14 biomass flux 0.786587516601523
# reference flux change -0.34435070984278116 -> -0.2410454968899468
# IPPMIb: 2ippm_c + h2o_c <-- 3c3hmp_c -1000.0 -0.2410454968899468
# error -1.841162664261567e-14 biomass flux 0.786587516601523
# reference flux change -0.34435070984278116 -> -0.2066104259056687
# IPPMIb: 2ippm_c + h2o_c <-- 3c3hmp_c -1000.0 -0.2066104259056687
# error -1.841162664261567e-14 biomass flux 0.786587516601523
# reference flux change 0.34435070984278116 -> 0.34435070984278116
# IPPS: 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c 0 0
# error 82.76247264038936 biomass flux 0.0
# reference flux change 0.34435070984278116 -> 0.2066104259056687
# IPPS: 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c 0.2066104259056687 1000.0
# error 4.3925531199755705e-13 biomass flux 0.7865875166015239
# reference flux change 0.34435070984278116 -> 0.2410454968899468
# IPPS: 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c 0.2410454968899468 1000.0
# error 1.1076082586528354e-14 biomass flux 0.7865875166015235
# reference flux change 0.34435070984278116 -> 0.2754805678742249
# IPPS: 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c 0.2754805678742249 1000.0
# error 1.8771255589493862e-14 biomass flux 0.7865875166015242
# reference flux change 0.34435070984278116 -> 0.30991563885850304
# IPPS: 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c 0.30991563885850304 1000.0
# error -5.392636265090645e-14 biomass flux 0.7865875166015214
# reference flux change 0.34435070984278116 -> 0.37878578082705927
# IPPS: 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c 0.37878578082705927 1000.0
# error 1.6441879164418964 biomass flux 0.7793450778067333
# reference flux change 0.34435070984278116 -> 0.4132208518113374
# IPPS: 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c 0.4132208518113374 1000.0
# error 3.288726868188587 biomass flux 0.7721026390119451
# reference flux change 0.34435070984278116 -> 0.4476559227956155
# IPPS: 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c 0.4476559227956155 1000.0
# error 4.933265711299695 biomass flux 0.7648602002171789
# reference flux change 0.34435070984278116 -> 0.4820909937798936
# IPPS: 3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c 0.4820909937798936 1000.0
# error 6.577803801195696 biomass flux 0.7576177614223852
# reference flux change 0.00045307440956232625 -> 0.00045307440956232625
# MOHMT: 3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c 0 0
# error 79.56380697471445 biomass flux 2.306078078956023e-12
# reference flux change 0.00045307440956232625 -> 0.0002718446457373958
# MOHMT: 3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c 0.0002718446457373958 1000.0
# error -1.7462450758315658e-14 biomass flux 0.7865875166015223
# reference flux change 0.00045307440956232625 -> 0.0003171520866936284
# MOHMT: 3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c 0.0003171520866936284 1000.0
# error -3.4299523514682674e-14 biomass flux 0.7865875166015228
# reference flux change 0.00045307440956232625 -> 0.000362459527649861
# MOHMT: 3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c 0.000362459527649861 1000.0
# error -1.9357901932190007e-14 biomass flux 0.7865875166015222
# reference flux change 0.00045307440956232625 -> 0.0004077669686060936
# MOHMT: 3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c 0.0004077669686060936 1000.0
# error -6.854322891330502e-14 biomass flux 0.7865875166015225
# reference flux change 0.00045307440956232625 -> 0.0004983818505185589
# MOHMT: 3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c 0.0004983818505185589 1000.0
# cobra/util/solver.py:408 UserWarning: solver status is 'infeasible'
# error -6.787073903688623e-13 biomass flux 0.7865875166015177
# reference flux change 0.00045307440956232625 -> 0.0005436892914747915
# MOHMT: 3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c 0.0005436892914747915 1000.0
# error -1.3818727756282904e-12 biomass flux 0.7865875166015187
# reference flux change 0.00045307440956232625 -> 0.0005889967324310241
# MOHMT: 3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c 0.0005889967324310241 1000.0
# error -4.831940035081121e-13 biomass flux 0.7865875166015166
# reference flux change 0.00045307440956232625 -> 0.0006343041733872567
# MOHMT: 3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c 0.0006343041733872567 1000.0
# error -1.7001795622504418e-12 biomass flux 0.7865875166015236
# reference flux change 0.0 -> 0.0
# OAADC: h_c + oaa_c --> co2_c + pyr_c 0 0
# error -2.3077428600889546e-13 biomass flux 0.7865875166015217
# reference flux change 0.0 -> 0.0
# OAADC: h_c + oaa_c --> co2_c + pyr_c 0.0 0.0
# error -2.3077428600889546e-13 biomass flux 0.7865875166015217
# reference flux change 0.0 -> 0.0
# OAADC: h_c + oaa_c --> co2_c + pyr_c 0.0 0.0
# error -2.3077428600889546e-13 biomass flux 0.7865875166015217
# reference flux change 0.0 -> 0.0
# OAADC: h_c + oaa_c --> co2_c + pyr_c 0.0 0.0
# error -2.3077428600889546e-13 biomass flux 0.7865875166015217
# reference flux change 0.0 -> 0.0
# OAADC: h_c + oaa_c --> co2_c + pyr_c 0.0 0.0
# error -2.3077428600889546e-13 biomass flux 0.7865875166015217
# reference flux change 0.0 -> 0.0
# OAADC: h_c + oaa_c --> co2_c + pyr_c 0.0 0.0
# error -2.3077428600889546e-13 biomass flux 0.7865875166015217
# reference flux change 0.0 -> 0.0
# OAADC: h_c + oaa_c --> co2_c + pyr_c 0.0 0.0
# error -2.3077428600889546e-13 biomass flux 0.7865875166015217
# reference flux change 0.0 -> 0.0
# OAADC: h_c + oaa_c --> co2_c + pyr_c 0.0 0.0
# error -2.3077428600889546e-13 biomass flux 0.7865875166015217
# reference flux change 0.0 -> 0.0
# OAADC: h_c + oaa_c --> co2_c + pyr_c 0.0 0.0
# error -2.3077428600889546e-13 biomass flux 0.7865875166015217
# reference flux change -2.2421118683589265 -> -2.2421118683589265
# ASPTA: akg_c + asp__L_c --> glu__L_c + oaa_c 0 0
# error 131.27037744233957 biomass flux -2.1417015559724857e-14
# reference flux change -2.2421118683589265 -> -3.1389566157024973
# ASPTA: akg_c + asp__L_c <-- glu__L_c + oaa_c -1000.0 -3.1389566157024973
# error 6.226557411139345 biomass flux 0.7791587845292565
# reference flux change -2.2421118683589265 -> -2.9147454288666044
# ASPTA: akg_c + asp__L_c <-- glu__L_c + oaa_c -1000.0 -2.9147454288666044
# error 4.669918295895437 biomass flux 0.7810159720884965
# reference flux change -2.2421118683589265 -> -2.690534242030712
# ASPTA: akg_c + asp__L_c <-- glu__L_c + oaa_c -1000.0 -2.690534242030712
# error 3.113278792009104 biomass flux 0.7828731520545011
# reference flux change -2.2421118683589265 -> -2.466323055194819
# ASPTA: akg_c + asp__L_c <-- glu__L_c + oaa_c -1000.0 -2.466323055194819
# error 1.55663939021359 biomass flux 0.7847303312068722
# reference flux change -2.2421118683589265 -> -2.017900681523034
# ASPTA: akg_c + asp__L_c <-- glu__L_c + oaa_c -1000.0 -2.017900681523034
# error -3.4032368813585646e-14 biomass flux 0.7865875166015227
# reference flux change -2.2421118683589265 -> -1.7936894946871411
# ASPTA: akg_c + asp__L_c <-- glu__L_c + oaa_c -1000.0 -1.7936894946871411
# error 1.0061185093559022e-13 biomass flux 0.7865875166015214
# reference flux change -2.2421118683589265 -> -1.5694783078512486
# ASPTA: akg_c + asp__L_c <-- glu__L_c + oaa_c -1000.0 -1.5694783078512486
# error 2.6170439361572497e-14 biomass flux 0.7865875166015218
# reference flux change -2.2421118683589265 -> -1.3452671210153557
# ASPTA: akg_c + asp__L_c <-- glu__L_c + oaa_c -1000.0 -1.3452671210153557
# error 1.3841413416566487e-13 biomass flux 0.7865875166015225
# reference flux change 0.00045307440956232625 -> 0.00045307440956232625
# ASP1DC: asp__L_c + h_c --> ala_B_c + co2_c 0 0
# error 79.56380697492665 biomass flux 2.2017344695444479e-13
# reference flux change 0.00045307440956232625 -> 0.0002718446457373958
# ASP1DC: asp__L_c + h_c --> ala_B_c + co2_c 0.0002718446457373958 1000.0
# error -1.1956643368185844e-14 biomass flux 0.7865875166015227
# reference flux change 0.00045307440956232625 -> 0.0003171520866936284
# ASP1DC: asp__L_c + h_c --> ala_B_c + co2_c 0.0003171520866936284 1000.0
# error 2.492371805819171e-15 biomass flux 0.7865875166015225
# reference flux change 0.00045307440956232625 -> 0.000362459527649861
# ASP1DC: asp__L_c + h_c --> ala_B_c + co2_c 0.000362459527649861 1000.0
# error -4.2189809437147296e-13 biomass flux 0.7865875166015222
# reference flux change 0.00045307440956232625 -> 0.0004077669686060936
# ASP1DC: asp__L_c + h_c --> ala_B_c + co2_c 0.0004077669686060936 1000.0
# error -3.418608918943087e-14 biomass flux 0.7865875166015217
# reference flux change 0.00045307440956232625 -> 0.0004983818505185589
# ASP1DC: asp__L_c + h_c --> ala_B_c + co2_c 0.0004983818505185589 1000.0
# error 0.0017103096059195553 biomass flux 0.7865852181826203
# reference flux change 0.00045307440956232625 -> 0.0005436892914747915
# ASP1DC: asp__L_c + h_c --> ala_B_c + co2_c 0.0005436892914747915 1000.0
# error 0.003385145525573533 biomass flux 0.7865828931840749
# reference flux change 0.00045307440956232625 -> 0.0005889967324310241
# ASP1DC: asp__L_c + h_c --> ala_B_c + co2_c 0.0005889967324310241 1000.0
# error 0.005044095105471128 biomass flux 0.7865805812304894
# reference flux change 0.00045307440956232625 -> 0.0006343041733872567
# ASP1DC: asp__L_c + h_c --> ala_B_c + co2_c 0.0006343041733872567 1000.0
# error 0.006804108895803491 biomass flux 0.7865782694401291
# reference flux change 0.8228822377925497 -> 0.8228822377925497
# ASPK: asp__L_c + atp_c --> 4pasp_c + adp_c 0 0
# error 87.63814760215742 biomass flux 0.0
# reference flux change 0.8228822377925497 -> 0.49372934267552976
# ASPK: asp__L_c + atp_c --> 4pasp_c + adp_c 0.49372934267552976 1000.0
# error 5.99248955820269e-15 biomass flux 0.7865875166015228
# reference flux change 0.8228822377925497 -> 0.5760175664547847
# ASPK: asp__L_c + atp_c --> 4pasp_c + adp_c 0.5760175664547847 1000.0
# error 7.989148258952118e-15 biomass flux 0.7865875166015207
# reference flux change 0.8228822377925497 -> 0.6583057902340397
# ASPK: asp__L_c + atp_c --> 4pasp_c + adp_c 0.6583057902340397 1000.0
# error 1.1770363452736922e-13 biomass flux 0.7865875166015178
# reference flux change 0.8228822377925497 -> 0.7405940140132947
# ASPK: asp__L_c + atp_c --> 4pasp_c + adp_c 0.7405940140132947 1000.0
# error 7.316420665781561e-14 biomass flux 0.7865875166015223
# reference flux change 0.8228822377925497 -> 0.9051704615718046
# ASPK: asp__L_c + atp_c --> 4pasp_c + adp_c 0.9051704615718046 1000.0
# error 1.9205160256697618 biomass flux 0.7822025760337089
# reference flux change 0.8228822377925497 -> 0.9874586853510596
# ASPK: asp__L_c + atp_c --> 4pasp_c + adp_c 0.9874586853510596 1000.0
# error 3.841031893482178 biomass flux 0.7778176354659035
# reference flux change 0.8228822377925497 -> 1.0697469091303144
# ASPK: asp__L_c + atp_c --> 4pasp_c + adp_c 1.0697469091303144 1000.0
# error 5.761548031232218 biomass flux 0.7734327078005215
# reference flux change 0.8228822377925497 -> 1.1520351329095695
# ASPK: asp__L_c + atp_c --> 4pasp_c + adp_c 1.1520351329095695 1000.0
# error 7.682064118738964 biomass flux 0.7690477698098094
# reference flux change -0.8228822377925497 -> -0.8228822377925497
# ASAD: aspsa_c + nadp_c + pi_c --> 4pasp_c + h_c + nadph_c 0 0
# error 87.63814760215732 biomass flux 0.0
# reference flux change -0.8228822377925497 -> -1.1520351329095695
# ASAD: aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + nadph_c -1000.0 -1.1520351329095695
# error 7.682064786606414 biomass flux 0.7690477712756861
# reference flux change -0.8228822377925497 -> -1.0697469091303144
# ASAD: aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + nadph_c -1000.0 -1.0697469091303144
# error 5.761548122135803 biomass flux 0.7734326955711568
# reference flux change -0.8228822377925497 -> -0.9874586853510596
# ASAD: aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + nadph_c -1000.0 -0.9874586853510596
# error 3.84103197618541 biomass flux 0.7778176359146118
# reference flux change -0.8228822377925497 -> -0.9051704615718046
# ASAD: aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + nadph_c -1000.0 -0.9051704615718046
# error 1.9205159116306831 biomass flux 0.7822025802700632
# reference flux change -0.8228822377925497 -> -0.7405940140132947
# ASAD: aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + nadph_c -1000.0 -0.7405940140132947
# error -8.938937984273748e-15 biomass flux 0.7865875166015233
# reference flux change -0.8228822377925497 -> -0.6583057902340397
# ASAD: aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + nadph_c -1000.0 -0.6583057902340397
# error 2.1468031599228928e-13 biomass flux 0.7865875166015212
# reference flux change -0.8228822377925497 -> -0.5760175664547847
# ASAD: aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + nadph_c -1000.0 -0.5760175664547847
# error 1.0407560864881623e-13 biomass flux 0.7865875166015239
# reference flux change -0.8228822377925497 -> -0.49372934267552976
# ASAD: aspsa_c + nadp_c + pi_c <-- 4pasp_c + h_c + nadph_c -1000.0 -0.49372934267552976
# error -1.6131344467157014e-13 biomass flux 0.7865875166015213
# reference flux change -0.2220583754617093 -> -0.2220583754617093
# ILETA: akg_c + ile__L_c --> 3mop_c + glu__L_c 0 0
# error 81.37377291723843 biomass flux 0.0
# reference flux change -0.2220583754617093 -> -0.31088172564639305
# ILETA: akg_c + ile__L_c <-- 3mop_c + glu__L_c -1000.0 -0.31088172564639305
# error 4.439806225889331 biomass flux 0.7687573006027264
# reference flux change -0.2220583754617093 -> -0.2886758881002221
# ILETA: akg_c + ile__L_c <-- 3mop_c + glu__L_c -1000.0 -0.2886758881002221
# error 3.329648616854103 biomass flux 0.773216615860253
# reference flux change -0.2220583754617093 -> -0.26647005055405115
# ILETA: akg_c + ile__L_c <-- 3mop_c + glu__L_c -1000.0 -0.26647005055405115
# error 2.219491007818211 biomass flux 0.7776759311177677
# reference flux change -0.2220583754617093 -> -0.24426421300788026
# ILETA: akg_c + ile__L_c <-- 3mop_c + glu__L_c -1000.0 -0.24426421300788026
# error 1.1093333854262073 biomass flux 0.7821352463752981
# reference flux change -0.2220583754617093 -> -0.19985253791553836
# ILETA: akg_c + ile__L_c <-- 3mop_c + glu__L_c -1000.0 -0.19985253791553836
# error 1.6462226634859778e-13 biomass flux 0.7865875166015243
# reference flux change -0.2220583754617093 -> -0.17764670036936744
# ILETA: akg_c + ile__L_c <-- 3mop_c + glu__L_c -1000.0 -0.17764670036936744
# error 1.738247111202365e-13 biomass flux 0.7865875166015222
# reference flux change -0.2220583754617093 -> -0.15544086282319652
# ILETA: akg_c + ile__L_c <-- 3mop_c + glu__L_c -1000.0 -0.15544086282319652
# error -1.355530684313625e-13 biomass flux 0.7865875166015222
# reference flux change -0.2220583754617093 -> -0.13323502527702558
# ILETA: akg_c + ile__L_c <-- 3mop_c + glu__L_c -1000.0 -0.13323502527702558
# error -3.5212882336288634e-14 biomass flux 0.7865875166015192
# reference flux change 0.2220583754617093 -> 0.2220583754617093
# DHAD2: 23dhmp_c --> 3mop_c + h2o_c 0 0
# error 81.37377291723939 biomass flux 0.0
# reference flux change 0.2220583754617093 -> 0.13323502527702558
# DHAD2: 23dhmp_c --> 3mop_c + h2o_c 0.13323502527702558 1000.0
# error 2.201631913073255e-14 biomass flux 0.7865875166015218
# reference flux change 0.2220583754617093 -> 0.15544086282319652
# DHAD2: 23dhmp_c --> 3mop_c + h2o_c 0.15544086282319652 1000.0
# error -7.570215022068786e-14 biomass flux 0.7865875166015223
# reference flux change 0.2220583754617093 -> 0.17764670036936744
# DHAD2: 23dhmp_c --> 3mop_c + h2o_c 0.17764670036936744 1000.0
# error -2.4003374719388232e-14 biomass flux 0.7865875166015218
# reference flux change 0.2220583754617093 -> 0.19985253791553836
# DHAD2: 23dhmp_c --> 3mop_c + h2o_c 0.19985253791553836 1000.0
# error -2.1765713573068756e-14 biomass flux 0.7865875166015222
# reference flux change 0.2220583754617093 -> 0.24426421300788026
# DHAD2: 23dhmp_c --> 3mop_c + h2o_c 0.24426421300788026 1000.0
# error 1.1093333587121088 biomass flux 0.7821352463752866
# reference flux change 0.2220583754617093 -> 0.26647005055405115
# DHAD2: 23dhmp_c --> 3mop_c + h2o_c 0.26647005055405115 1000.0
# error 2.2194909810831955 biomass flux 0.7776759311177641
# reference flux change 0.2220583754617093 -> 0.2886758881002221
# DHAD2: 23dhmp_c --> 3mop_c + h2o_c 0.2886758881002221 1000.0
# error 3.3296485767411004 biomass flux 0.7732166158602501
# reference flux change 0.2220583754617093 -> 0.31088172564639305
# DHAD2: 23dhmp_c --> 3mop_c + h2o_c 0.31088172564639305 1000.0
# error 4.439806172398997 biomass flux 0.7687573006027331
# reference flux change 0.2220583754617093 -> 0.2220583754617093
# KARA2: 2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c 0 0
# error 81.37377291723912 biomass flux 0.0
# reference flux change 0.2220583754617093 -> 0.13323502527702558
# KARA2: 2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c 0.13323502527702558 1000.0
# error -4.5723488324005933e-14 biomass flux 0.7865875166015223
# reference flux change 0.2220583754617093 -> 0.15544086282319652
# KARA2: 2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c 0.15544086282319652 1000.0
# error -7.851510425868399e-14 biomass flux 0.7865875166015222
# reference flux change 0.2220583754617093 -> 0.17764670036936744
# KARA2: 2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c 0.17764670036936744 1000.0
# error -2.490126888255374e-14 biomass flux 0.7865875166015222
# reference flux change 0.2220583754617093 -> 0.19985253791553836
# KARA2: 2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c 0.19985253791553836 1000.0
# error 2.2764607320840275e-14 biomass flux 0.7865875166015222
# reference flux change 0.2220583754617093 -> 0.24426421300788026
# KARA2: 2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c 0.24426421300788026 1000.0
# error 1.1093332385013897 biomass flux 0.7821352463752957
# reference flux change 0.2220583754617093 -> 0.26647005055405115
# KARA2: 2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c 0.26647005055405115 1000.0
# error 2.2194905978850663 biomass flux 0.7776759311177658
# reference flux change 0.2220583754617093 -> 0.2886758881002221
# KARA2: 2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c 0.2886758881002221 1000.0
# error 3.329648188985013 biomass flux 0.7732166158602489
# reference flux change 0.2220583754617093 -> 0.31088172564639305
# KARA2: 2ahbut_c + h_c + nadph_c --> 23dhmp_c + nadp_c 0.31088172564639305 1000.0
# error 4.439806225889035 biomass flux 0.7687573006027258
# reference flux change 0.2220583754617093 -> 0.2220583754617093
# ACHBS: 2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c 0 0
# error 81.37377291723949 biomass flux 0.0
# reference flux change 0.2220583754617093 -> 0.13323502527702558
# ACHBS: 2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c 0.13323502527702558 1000.0
# error 2.421556710796028e-13 biomass flux 0.7865875166015225
# reference flux change 0.2220583754617093 -> 0.15544086282319652
# ACHBS: 2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c 0.15544086282319652 1000.0
# error -1.1450085753526385e-15 biomass flux 0.786587516601524
# reference flux change 0.2220583754617093 -> 0.17764670036936744
# ACHBS: 2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c 0.17764670036936744 1000.0
# error -9.765225265313989e-14 biomass flux 0.7865875166015186
# ...
# reference flux change -0.538904479611485 -> -0.3772331357280395
# HSDy: hom__L_c + nadp_c <-- aspsa_c + h_c + nadph_c -1000.0 -0.3772331357280395
# error -2.179323380098258e-13 biomass flux 0.7865875166015238
# reference flux change -0.538904479611485 -> -0.323342687766891
# HSDy: hom__L_c + nadp_c <-- aspsa_c + h_c + nadph_c -1000.0 -0.323342687766891
# error -1.1739490885109064e-13 biomass flux 0.7865875166015216
# reference flux change 0.2839777581810646 -> 0.2839777581810646
# DHDPS: aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c 0 0
# error 83.44127206834351 biomass flux 0.0
# reference flux change 0.2839777581810646 -> 0.17038665490863875
# DHDPS: aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c 0.17038665490863875 1000.0
# error 1.4909775313144012e-14 biomass flux 0.7865875166015222
# reference flux change 0.2839777581810646 -> 0.1987844307267452
# DHDPS: aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c 0.1987844307267452 1000.0
# error 3.667052298228562e-13 biomass flux 0.7865875166015142
# reference flux change 0.2839777581810646 -> 0.22718220654485166
# DHDPS: aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c 0.22718220654485166 1000.0
# error 3.700275099945627e-14 biomass flux 0.7865875166015214
# reference flux change 0.2839777581810646 -> 0.2555799823629581
# DHDPS: aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c 0.2555799823629581 1000.0
# error -8.031501459037188e-14 biomass flux 0.7865875166015245
# reference flux change 0.2839777581810646 -> 0.31237553399917106
# DHDPS: aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c 0.31237553399917106 1000.0
# error 1.2858017333384555 biomass flux 0.7813174719205691
# reference flux change 0.2839777581810646 -> 0.3407733098172775
# DHDPS: aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c 0.3407733098172775 1000.0
# error 2.5723546058687567 biomass flux 0.7760399044436456
# reference flux change 0.2839777581810646 -> 0.3691710856353839
# DHDPS: aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c 0.3691710856353839 1000.0
# error 3.858907446778835 biomass flux 0.7707623369667196
# reference flux change 0.2839777581810646 -> 0.3975688614534904
# DHDPS: aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c 0.3975688614534904 1000.0
# error 5.145460287688781 biomass flux 0.7654847694897743
# reference flux change 0.2839777581810646 -> 0.2839777581810646
# DHDPRy: 23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c 0 0
# error 83.44127206834366 biomass flux 0.0
# reference flux change 0.2839777581810646 -> 0.17038665490863875
# DHDPRy: 23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c 0.17038665490863875 1000.0
# error -9.833283832736522e-15 biomass flux 0.7865875166015218
# reference flux change 0.2839777581810646 -> 0.1987844307267452
# DHDPRy: 23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c 0.1987844307267452 1000.0
# error -1.3837160550248665e-13 biomass flux 0.7865875166015219
# reference flux change 0.2839777581810646 -> 0.22718220654485166
# DHDPRy: 23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c 0.22718220654485166 1000.0
# error -1.7882683398730794e-15 biomass flux 0.7865875166015218
# reference flux change 0.2839777581810646 -> 0.2555799823629581
# DHDPRy: 23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c 0.2555799823629581 1000.0
# error -7.43870400454487e-14 biomass flux 0.7865875166015215
# reference flux change 0.2839777581810646 -> 0.31237553399917106
# DHDPRy: 23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c 0.31237553399917106 1000.0
# error 1.285801688542695 biomass flux 0.7813174719205727
# reference flux change 0.2839777581810646 -> 0.3407733098172775
# DHDPRy: 23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c 0.3407733098172775 1000.0
# error 2.5723548484636294 biomass flux 0.7760399044436395
# reference flux change 0.2839777581810646 -> 0.3691710856353839
# DHDPRy: 23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c 0.3691710856353839 1000.0
# error 3.8589080481355644 biomass flux 0.7707623369667136
# reference flux change 0.2839777581810646 -> 0.3975688614534904
# DHDPRy: 23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c 0.3975688614534904 1000.0
# error 5.145461068490573 biomass flux 0.7654847694897982
# reference flux change 0.2839777581810646 -> 0.2839777581810646
# THDPS: h2o_c + succoa_c + thdp_c --> coa_c + sl2a6o_c 0 0
# error 83.44127206834295 biomass flux 0.0
# reference flux change 0.2839777581810646 -> 0.17038665490863875
# THDPS: h2o_c + succoa_c + thdp_c --> coa_c + sl2a6o_c 0.17038665490863875 1000.0
# error -3.403443750007644e-14 biomass flux 0.7865875166015222
# reference flux change 0.2839777581810646 -> 0.1987844307267452
# THDPS: h2o_c + succoa_c + thdp_c --> coa_c + sl2a6o_c 0.1987844307267452 1000.0
# error 2.026869828314123e-14 biomass flux 0.7865875166015222
# reference flux change 0.2839777581810646 -> 0.22718220654485166
# THDPS: h2o_c + succoa_c + thdp_c --> coa_c + sl2a6o_c 0.22718220654485166 1000.0
# error -6.313419704658657e-14 biomass flux 0.7865875166015223
# reference flux change 0.2839777581810646 -> 0.2555799823629581
# THDPS: h2o_c + succoa_c + thdp_c --> coa_c + sl2a6o_c 0.2555799823629581 1000.0
# error -9.353903094071035e-16 biomass flux 0.7865875166015203
# reference flux change 0.2839777581810646 -> 0.31237553399917106
# THDPS: h2o_c + succoa_c + thdp_c --> coa_c + sl2a6o_c 0.31237553399917106 1000.0
# error 1.2858018808995029 biomass flux 0.7813174719205663
# reference flux change 0.2839777581810646 -> 0.3407733098172775
# THDPS: h2o_c + succoa_c + thdp_c --> coa_c + sl2a6o_c 0.3407733098172775 1000.0
# error 2.572354943392288 biomass flux 0.7760399044436446
# reference flux change 0.2839777581810646 -> 0.3691710856353839
# THDPS: h2o_c + succoa_c + thdp_c --> coa_c + sl2a6o_c 0.3691710856353839 1000.0
# error 3.858908000660429 biomass flux 0.7707623369667279
# reference flux change 0.2839777581810646 -> 0.3975688614534904
# THDPS: h2o_c + succoa_c + thdp_c --> coa_c + sl2a6o_c 0.3975688614534904 1000.0
# error 5.1454610895933355 biomass flux 0.7654847694897897
# reference flux change -0.2839777581810646 -> -0.2839777581810646
# SDPTA: akg_c + sl26da_c --> glu__L_c + sl2a6o_c 0 0
# error 83.44127206834335 biomass flux 0.0
# reference flux change -0.2839777581810646 -> -0.3975688614534904
# SDPTA: akg_c + sl26da_c <-- glu__L_c + sl2a6o_c -1000.0 -0.3975688614534904
# error 5.145461089593418 biomass flux 0.7654847694897807
# reference flux change -0.2839777581810646 -> -0.3691710856353839
# SDPTA: akg_c + sl26da_c <-- glu__L_c + sl2a6o_c -1000.0 -0.3691710856353839
# error 3.8589080006593206 biomass flux 0.770762336966723
# reference flux change -0.2839777581810646 -> -0.3407733098172775
# SDPTA: akg_c + sl26da_c <-- glu__L_c + sl2a6o_c -1000.0 -0.3407733098172775
# error 2.572354975035065 biomass flux 0.7760399044436371
# reference flux change -0.2839777581810646 -> -0.31237553399917106
# SDPTA: akg_c + sl26da_c <-- glu__L_c + sl2a6o_c -1000.0 -0.31237553399917106
# error 1.2858019494100343 biomass flux 0.7813174719205626
# reference flux change -0.2839777581810646 -> -0.2555799823629581
# SDPTA: akg_c + sl26da_c <-- glu__L_c + sl2a6o_c -1000.0 -0.2555799823629581
# error 3.0213861807369107e-13 biomass flux 0.7865875166015214
# reference flux change -0.2839777581810646 -> -0.22718220654485166
# SDPTA: akg_c + sl26da_c <-- glu__L_c + sl2a6o_c -1000.0 -0.22718220654485166
# error 4.7105304469223315e-14 biomass flux 0.7865875166015222
# reference flux change -0.2839777581810646 -> -0.1987844307267452
# SDPTA: akg_c + sl26da_c <-- glu__L_c + sl2a6o_c -1000.0 -0.1987844307267452
# error 2.6138094123658007e-14 biomass flux 0.7865875166015216
# reference flux change -0.2839777581810646 -> -0.17038665490863875
# SDPTA: akg_c + sl26da_c <-- glu__L_c + sl2a6o_c -1000.0 -0.17038665490863875
# error 2.107431944115783e-14 biomass flux 0.7865875166015222
# reference flux change 0.2839777581810646 -> 0.2839777581810646
# SDPDS: h2o_c + sl26da_c --> 26dap_LL_c + succ_c 0 0
# error 83.44127206834365 biomass flux 0.0
# reference flux change 0.2839777581810646 -> 0.17038665490863875
# SDPDS: h2o_c + sl26da_c --> 26dap_LL_c + succ_c 0.17038665490863875 1000.0
# error 8.567103204186819e-14 biomass flux 0.7865875166015229
# reference flux change 0.2839777581810646 -> 0.1987844307267452
# SDPDS: h2o_c + sl26da_c --> 26dap_LL_c + succ_c 0.1987844307267452 1000.0
# error -1.5962738420152328e-13 biomass flux 0.7865875166015236
# reference flux change 0.2839777581810646 -> 0.22718220654485166
# SDPDS: h2o_c + sl26da_c --> 26dap_LL_c + succ_c 0.22718220654485166 1000.0
# error -1.5081207554217878e-14 biomass flux 0.7865875166015222
# reference flux change 0.2839777581810646 -> 0.2555799823629581
# SDPDS: h2o_c + sl26da_c --> 26dap_LL_c + succ_c 0.2555799823629581 1000.0
# error 1.3094346327314682e-13 biomass flux 0.7865875166015222
# reference flux change 0.2839777581810646 -> 0.31237553399917106
# SDPDS: h2o_c + sl26da_c --> 26dap_LL_c + succ_c 0.31237553399917106 1000.0
# error 1.285801965220025 biomass flux 0.7813174719205704
# reference flux change 0.2839777581810646 -> 0.3407733098172775
# SDPDS: h2o_c + sl26da_c --> 26dap_LL_c + succ_c 0.3407733098172775 1000.0
# error 2.5723546797019154 biomass flux 0.776039904443646
# reference flux change 0.2839777581810646 -> 0.3691710856353839
# SDPDS: h2o_c + sl26da_c --> 26dap_LL_c + succ_c 0.3691710856353839 1000.0
# error 3.8589073518272015 biomass flux 0.7707623369667063
# reference flux change 0.2839777581810646 -> 0.3975688614534904
# SDPDS: h2o_c + sl26da_c --> 26dap_LL_c + succ_c 0.3975688614534904 1000.0
# error 5.145460962976683 biomass flux 0.7654847694897916
# reference flux change 0.2839777581810646 -> 0.2839777581810646
# DAPE: 26dap_LL_c --> 26dap__M_c 0 0
# error 83.44127206834342 biomass flux 0.0
# reference flux change 0.2839777581810646 -> 0.17038665490863875
# DAPE: 26dap_LL_c --> 26dap__M_c 0.17038665490863875 1000.0
# error 8.481491151495739e-14 biomass flux 0.7865875166015232
# reference flux change 0.2839777581810646 -> 0.1987844307267452
# DAPE: 26dap_LL_c --> 26dap__M_c 0.1987844307267452 1000.0
# error -3.846332636208379e-14 biomass flux 0.7865875166015229
# reference flux change 0.2839777581810646 -> 0.22718220654485166
# DAPE: 26dap_LL_c --> 26dap__M_c 0.22718220654485166 1000.0
# error 1.0322385399897402e-13 biomass flux 0.7865875166015218
# reference flux change 0.2839777581810646 -> 0.2555799823629581
# DAPE: 26dap_LL_c --> 26dap__M_c 0.2555799823629581 1000.0
# error 2.9206950361566985e-15 biomass flux 0.7865875166015222
# reference flux change 0.2839777581810646 -> 0.31237553399917106
# DAPE: 26dap_LL_c --> 26dap__M_c 0.31237553399917106 1000.0
# error 1.2858018914393827 biomass flux 0.7813174719205672
# reference flux change 0.2839777581810646 -> 0.3407733098172775
# DAPE: 26dap_LL_c --> 26dap__M_c 0.3407733098172775 1000.0
# error 2.5723550066778222 biomass flux 0.776039904443644
# reference flux change 0.2839777581810646 -> 0.3691710856353839
# DAPE: 26dap_LL_c --> 26dap__M_c 0.3691710856353839 1000.0
# error 3.858908048135613 biomass flux 0.7707623369667205
# reference flux change 0.2839777581810646 -> 0.3975688614534904
# DAPE: 26dap_LL_c --> 26dap__M_c 0.3975688614534904 1000.0
# error 5.145461089593328 biomass flux 0.7654847694897964
# reference flux change 0.26228603423574437 -> 0.26228603423574437
# DAPDC: 26dap__M_c + h_c --> co2_c + lys__L_c 0 0
# error 82.24922631317882 biomass flux 0.0
# reference flux change 0.26228603423574437 -> 0.1573716205414466
# DAPDC: 26dap__M_c + h_c --> co2_c + lys__L_c 0.1573716205414466 1000.0
# error -1.4077116291012685e-14 biomass flux 0.7865875166015217
# reference flux change 0.26228603423574437 -> 0.18360022396502107
# DAPDC: 26dap__M_c + h_c --> co2_c + lys__L_c 0.18360022396502107 1000.0
# error 6.195006839712734e-14 biomass flux 0.7865875166015229
# reference flux change 0.26228603423574437 -> 0.20982882738859548
# DAPDC: 26dap__M_c + h_c --> co2_c + lys__L_c 0.20982882738859548 1000.0
# error 8.244515532290965e-14 biomass flux 0.7865875166015242
# reference flux change 0.26228603423574437 -> 0.23605743081216993
# DAPDC: 26dap__M_c + h_c --> co2_c + lys__L_c 0.23605743081216993 1000.0
# error 1.4103224669822227e-13 biomass flux 0.7865875166015222
# reference flux change 0.26228603423574437 -> 0.2885146376593188
# DAPDC: 26dap__M_c + h_c --> co2_c + lys__L_c 0.2885146376593188 1000.0
# error 1.1814784767173847 biomass flux 0.7817454163659854
# reference flux change 0.26228603423574437 -> 0.31474324108289325
# DAPDC: 26dap__M_c + h_c --> co2_c + lys__L_c 0.31474324108289325 1000.0
# error 2.363698794856004 biomass flux 0.7768958316924399
# reference flux change 0.26228603423574437 -> 0.34097184450646767
# DAPDC: 26dap__M_c + h_c --> co2_c + lys__L_c 0.34097184450646767 1000.0
# error 3.54591890947613 biomass flux 0.7720462470189274
# reference flux change 0.26228603423574437 -> 0.36720044793004214
# DAPDC: 26dap__M_c + h_c --> co2_c + lys__L_c 0.36720044793004214 1000.0
# error 4.728139857865747 biomass flux 0.7671966623453825
# reference flux change 0.0 -> 0.0
# LADGMDH: LalaDgluMdap_c + h2o_c --> 26dap__M_c + LalaDglu_c 0 0
# error -2.3522637725354556e-13 biomass flux 0.7865875166015254
# reference flux change 0.0 -> 0.0
# LADGMDH: LalaDgluMdap_c + h2o_c --> 26dap__M_c + LalaDglu_c 0.0 0.0
# error -2.3522637725354556e-13 biomass flux 0.7865875166015254
# reference flux change 0.0 -> 0.0
# LADGMDH: LalaDgluMdap_c + h2o_c --> 26dap__M_c + LalaDglu_c 0.0 0.0
# error -2.3522637725354556e-13 biomass flux 0.7865875166015254
# reference flux change 0.0 -> 0.0
# LADGMDH: LalaDgluMdap_c + h2o_c --> 26dap__M_c + LalaDglu_c 0.0 0.0
# error -2.3522637725354556e-13 biomass flux 0.7865875166015254
# reference flux change 0.0 -> 0.0
# LADGMDH: LalaDgluMdap_c + h2o_c --> 26dap__M_c + LalaDglu_c 0.0 0.0
# error -2.3522637725354556e-13 biomass flux 0.7865875166015254
# reference flux change 0.0 -> 0.0
# LADGMDH: LalaDgluMdap_c + h2o_c --> 26dap__M_c + LalaDglu_c 0.0 0.0
# error -2.3522637725354556e-13 biomass flux 0.7865875166015254
# reference flux change 0.0 -> 0.0
# LADGMDH: LalaDgluMdap_c + h2o_c --> 26dap__M_c + LalaDglu_c 0.0 0.0
# error -2.3522637725354556e-13 biomass flux 0.7865875166015254
# reference flux change 0.0 -> 0.0
# LADGMDH: LalaDgluMdap_c + h2o_c --> 26dap__M_c + LalaDglu_c 0.0 0.0
# error -2.3522637725354556e-13 biomass flux 0.7865875166015254
# reference flux change 0.0 -> 0.0
# LADGMDH: LalaDgluMdap_c + h2o_c --> 26dap__M_c + LalaDglu_c 0.0 0.0
# error -2.3522637725354556e-13 biomass flux 0.7865875166015254
# reference flux change 0.021691723945320176 -> 0.021691723945320176
# UAAGDS: 26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c 0 0
# error 79.98886537484138 biomass flux 0.0
# reference flux change 0.021691723945320176 -> 0.013015034367192105
# UAAGDS: 26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c 0.013015034367192105 1000.0
# error 2.2986642696290978e-14 biomass flux 0.786587516601522
# reference flux change 0.021691723945320176 -> 0.015184206761724123
# UAAGDS: 26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c 0.015184206761724123 1000.0
# error 1.2862900689696151e-14 biomass flux 0.7865875166015208
# reference flux change 0.021691723945320176 -> 0.017353379156256142
# UAAGDS: 26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c 0.017353379156256142 1000.0
# error 1.514600737054913e-14 biomass flux 0.7865875166015236
# reference flux change 0.021691723945320176 -> 0.019522551550788157
# UAAGDS: 26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c 0.019522551550788157 1000.0
# error -5.584863741254812e-14 biomass flux 0.7865875166015245
# reference flux change 0.021691723945320176 -> 0.023860896339852194
# UAAGDS: 26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c 0.023860896339852194 1000.0
# error 0.11474498105626248 biomass flux 0.7861332913507622
# reference flux change 0.021691723945320176 -> 0.02603006873438421
# UAAGDS: 26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c 0.02603006873438421 1000.0
# error 0.229490493564127 biomass flux 0.7856790355448817
# reference flux change 0.021691723945320176 -> 0.02819924112891623
# UAAGDS: 26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c 0.02819924112891623 1000.0
# error 0.34423572671845 biomass flux 0.7852247950165616
# reference flux change 0.021691723945320176 -> 0.030368413523448247
# UAAGDS: 26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c 0.030368413523448247 1000.0
# error 0.4589809298868953 biomass flux 0.7847705538883327

# %%
draw_escher(all_solutions['DHAD1'][0.2],'map_v1').display_in_notebook()
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="yjgyoxvssv"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"yjgyoxvssv"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "zoom", "enable_keys": false, "enable_editing": false, "scroll_behavior": "none", "fill_screen": false, "ignore_bootstrap": true, "never_ask_before_quit": true, "reaction_data": {"DM_4crsol_c": 0.00017027640820314478, "DM_5drib_c": 0.00017638497890101545, "DM_aacald_c": 0.0, "DM_amob_c": 1.5271426744676661e-06, "DM_mththf_c": 0.0010231855918933362, "DM_oxam_c": 0.0, "BIOMASS_Ec_iJO1366_WT_53p95M": 0.7635713372338331, "BIOMASS_Ec_iJO1366_core_53p95M": 0.0, "EX_12ppd__R_e": 0.0, "EX_12ppd__S_e": 0.0, "EX_14glucan_e": 0.0, "EX_15dap_e": 0.0, "EX_23camp_e": 0.0, "EX_23ccmp_e": 0.0, "EX_23cgmp_e": 0.0, "EX_23cump_e": 0.0, "EX_23dappa_e": 0.0, "EX_26dap__M_e": 0.0, "EX_2ddglcn_e": 0.0, "EX_34dhpac_e": 0.0, "EX_3amp_e": 0.0, "EX_3cmp_e": 0.0, "EX_3gmp_e": 0.0, "EX_3hcinnm_e": 0.0, "EX_3hpp_e": 0.0, "EX_3hpppn_e": 0.0, "EX_3ump_e": 0.0, "EX_4abut_e": 0.0, "EX_4hoxpacd_e": 0.0, "EX_5dglcn_e": 0.0, "EX_5mtr_e": 0.00514952509830497, "EX_LalaDglu_e": 0.0, "EX_LalaDgluMdap_e": 0.0, "EX_LalaDgluMdapDala_e": 0.0, "EX_LalaLglu_e": 0.0, "EX_ac_e": 0.0, "EX_acac_e": 0.0, "EX_acald_e": 0.0, "EX_acgal_e": 0.0, "EX_acgal1p_e": 0.0, "EX_acgam_e": 0.0, "EX_acgam1p_e": 0.0, "EX_acmana_e": 0.0, "EX_acmum_e": 0.0, "EX_acnam_e": 0.0, "EX_acolipa_e": 0.0, "EX_acser_e": 0.0, "EX_ade_e": 0.00668302387353934, "EX_adn_e": 0.0, "EX_adocbl_e": 0.0, "EX_ag_e": 0.0, "EX_agm_e": 0.0, "EX_akg_e": 0.0, "EX_ala_B_e": 0.0, "EX_ala__D_e": 0.0, "EX_ala__L_e": 0.0, "EX_alaala_e": 0.0, "EX_all__D_e": 0.0, "EX_alltn_e": 0.0, "EX_amp_e": 0.0, "EX_anhgm_e": 0.0, "EX_arab__L_e": 0.0, "EX_arbt_e": 0.0, "EX_arbtn_e": 0.0, "EX_arbtn_fe3_e": 0.0, "EX_arg__L_e": 0.0, "EX_ascb__L_e": 0.0, "EX_asn__L_e": 0.0, "EX_aso3_e": 0.0, "EX_asp__L_e": 0.0, "EX_btn_e": 0.0, "EX_but_e": 0.0, "EX_butso3_e": 0.0, "EX_ca2_e": -0.003781205261981941, "EX_cbi_e": 0.0, "EX_cbl1_e": -0.00017027640820314478, "EX_cd2_e": 0.0, "EX_cgly_e": 0.0, "EX_chol_e": 0.0, "EX_chtbs_e": 0.0, "EX_cit_e": 0.0, "EX_cl_e": -0.003781205261981941, "EX_cm_e": 0.0, "EX_cmp_e": 0.0, "EX_co2_e": 15.903709634163688, "EX_cobalt2_e": -1.8325712093611993e-05, "EX_colipa_e": 0.0, "EX_colipap_e": 0.0, "EX_cpgn_e": 0.0, "EX_cpgn_un_e": 0.0, "EX_crn_e": 0.0, "EX_crn__D_e": 0.0, "EX_csn_e": 0.0, "EX_cu_e": 0.0, "EX_cu2_e": -0.0005146470812956035, "EX_cyan_e": 0.0, "EX_cynt_e": 0.0, "EX_cys__D_e": 0.0, "EX_cys__L_e": 0.0, "EX_cytd_e": 0.0, "EX_dad_2_e": 0.0, "EX_damp_e": 0.0, "EX_dca_e": 0.0, "EX_dcmp_e": 0.0, "EX_dcyt_e": 0.0, "EX_ddca_e": 0.0, "EX_dgmp_e": 0.0, "EX_dgsn_e": 0.0, "EX_dha_e": 0.0, "EX_dimp_e": 0.0, "EX_din_e": 0.0, "EX_dms_e": 0.0, "EX_dmso_e": 0.0, "EX_dopa_e": 0.0, "EX_doxrbcn_e": 0.0, "EX_dtmp_e": 0.0, "EX_dump_e": 0.0, "EX_duri_e": 0.0, "EX_eca4colipa_e": 0.0, "EX_enlipa_e": 0.0, "EX_enter_e": 0.0, "EX_etha_e": 0.0, "EX_ethso3_e": 0.0, "EX_etoh_e": 0.0, "EX_f6p_e": 0.0, "EX_fald_e": 0.0, "EX_fe2_e": -0.012213344370271835, "EX_fe3_e": 0.00035737221704396777, "EX_fe3dcit_e": 0.0, "EX_fe3dhbzs_e": 0.0, "EX_fe3hox_e": 0.0, "EX_fe3hox_un_e": 0.0, "EX_fecrm_e": 0.0, "EX_fecrm_un_e": 0.0, "EX_feenter_e": 0.0, "EX_feoxam_e": 0.0, "EX_feoxam_un_e": 0.0, "EX_for_e": 0.0, "EX_fru_e": 0.0, "EX_frulys_e": 0.0, "EX_fruur_e": 0.0, "EX_fuc__L_e": 0.0, "EX_fum_e": 0.0, "EX_fusa_e": 0.0, "EX_g1p_e": 0.0, "EX_g3pc_e": 0.0, "EX_g3pe_e": 0.0, "EX_g3pg_e": 0.0, "EX_g3pi_e": 0.0, "EX_g3ps_e": 0.0, "EX_g6p_e": 0.0, "EX_gal_e": 0.0, "EX_gal_bD_e": 0.0, "EX_gal1p_e": 0.0, "EX_galct__D_e": 0.0, "EX_galctn__D_e": 0.0, "EX_galctn__L_e": 0.0, "EX_galt_e": 0.0, "EX_galur_e": 0.0, "EX_gam_e": 0.0, "EX_gam6p_e": 0.0, "EX_gbbtn_e": 0.0, "EX_gdp_e": 0.0, "EX_glc__D_e": -8.0, "EX_glcn_e": 0.0, "EX_glcr_e": 0.0, "EX_glcur_e": 0.0, "EX_glcur1p_e": 0.0, "EX_gln__L_e": 0.0, "EX_glu__L_e": 0.0, "EX_gly_e": 0.0, "EX_glyald_e": 0.0, "EX_glyb_e": 0.0, "EX_glyc_e": 0.0, "EX_glyc__R_e": 0.0, "EX_glyc2p_e": 0.0, "EX_glyc3p_e": 0.0, "EX_glyclt_e": 0.0, "EX_gmp_e": 0.0, "EX_gsn_e": 0.0, "EX_gthox_e": 0.0, "EX_gthrd_e" ...

# %%
x_data = {}
for r in all_solutions:
    x_data[r] = {}
    for fold in all_solutions[r]:
        x_data[r][fold] = {}
        growth = all_solutions[r][fold].fluxes[model_biomass]
        if not growth == 0:
            rxn_change = {}
            top_changes = {}
            solution = all_solutions[r][fold]
            for rxn in model.reactions:
                #solution.fluxes.
                reference_flux = pfba_solution.fluxes[rxn.id]
                moma_flux = solution.fluxes[rxn.id]
                diff_flux = reference_flux - moma_flux
                
                #print(diff_flux)
                if abs(diff_flux) > E_VALUE:
                    change = 1 - (moma_flux / reference_flux)
                    rxn_change[rxn.id] = change
                    
                    if not isinf(change) and not change in top_changes:
                        top_changes[change] = []
                    if not isinf(change):
                        top_changes[change].append(rxn.id)
                    #print(r, f, rxn.id, reference_flux, moma_flux, diff_flux, change)
                    
            values = list(top_changes.keys())
            values.sort(reverse=True)
            for i in range(5):
                if len(values) > (i + 1):
                    #print('Rank', i,values[i])
                    for rxn_id in top_changes[values[i]]:
                        reference_flux = pfba_solution.fluxes[rxn_id]
                        moma_flux = solution.fluxes[rxn_id]
                        diff_flux = reference_flux - moma_flux
                        change = 1 - (moma_flux / reference_flux)
                        x_data[r][fold][rxn_id] = values[i]
                        #print(values[i], rxn_id, reference_flux, moma_flux, diff_flux, change)
            
            
            
            #print(r, fold , solution.fluxes[model_biomass])
            #break
    #break
# Out:
# /Users/jplfaria/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19 RuntimeWarning: divide by zero encountered in double_scalars

# %%
import numpy as np
import pandas as pd


index = []
data_points = []
rxn_index = {}
i_value = 0
for target in x_data:
    for fold in x_data[target]:
        change_data = x_data[target][fold]
        for rxn_id in x_data[target][fold]:
            #print(rxn_id, change_data[rxn_id])
            if not rxn_id in rxn_index:
                rxn_index[rxn_id] = i_value
                i_value += 1
                index.append(rxn_id)
                
#print('index',len(index))
for r in index:
    data_points.append([])

k = 0
for target in x_data:
    for fold in x_data[target]:        
        solution_points = []
        for r in index:
            v = 0
            if r in x_data[target][fold]:
                 v = x_data[target][fold][r]
            #print(r, v)
            data_points[k].append(v)
        #print(len(solution_points))
        #data_points.append(solution_points)
        
        k += 1

pd = pd.DataFrame(data_points, index=index)
#print(rxn_index)
#print(x_data)
#figure(figsize=(24,12))
pd.plot(kind='bar', figsize=(24,12))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-256ed7b13d81> in <module>()
#      30                  v = x_data[target][fold][r]
#      31             #print(r, v)
# ---> 32             data_points[k].append(v)
#      33         #print(len(solution_points))
#      34         #data_points.append(solution_points)
#
# IndexError: list index out of range

# %%
len(all_solutions)
all_solutions['KARA1'].keys()
all_solutions.keys()
# Out:
# dict_keys(['DHAD1', 'KARA1', 'ACLS', 'VALtex', 'VALt2rpp', 'LEUtex', 'LEUt2rpp', 'ILEtex', 'ILEt2rpp', 'CADVtpp', 'LYStex', 'DAPabcpp', '26DAHtex', 'VPAMTr', 'VALTA', 'LEUTAi', 'OMCDC', 'IPMD', 'IPPMIa', 'IPPMIb', 'IPPS', 'MOHMT', 'OAADC', 'ASPTA', 'ASP1DC', 'ASPK', 'ASAD', 'ILETA', 'DHAD2', 'KARA2', 'ACHBS', 'OBTFL', 'THRD_L', 'THRS', 'HSK', 'HSDy', 'DHDPS', 'DHDPRy', 'THDPS', 'SDPTA', 'SDPDS', 'DAPE', 'DAPDC', 'LADGMDH', 'UAAGDS', 'WT'])

# %%
all_solutions['WT'] = {}

# %%
all_solutions['WT']['pFBA'] = pfba_solution

# %%
#data['target']['fold']['rxn'] = flux
def get_flux_dict(solution, model):
    flux_dict={}
    for r in model.reactions:
        flux_dict[r.id]=solution.fluxes[r.id]
    return flux_dict

data = {}
for target in all_solutions:
    if not target in data:
        data[target] = {}
    for fold in all_solutions[target]:
        solution = all_solutions[target][fold]
        flux_map = get_flux_dict(solution, model)
        data[target][fold] = flux_map

# %%
with open('./moma_fluxes.json', 'w') as f:
    json.dump(data, f)
